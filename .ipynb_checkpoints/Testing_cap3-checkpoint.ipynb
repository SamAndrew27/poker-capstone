# %%
import pandas as pd
from datetime import datetime
import numpy as np 
pd.set_option('display.max_columns', None)
from datetime import timedelta
import sqlite3
from src.datacleaning.create_df import load_df, impelement_column_creation
from src.datacleaning.columns_from_hand_history import fill_HH_columns
from src.datacleaning.time_columns import fill_time_columns
from src.datacleaning.dependent_columns import fill_dependent_columns
from src.datacleaning.betting_columns_CALL_LAST import fill_betting_columns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-74db4a5ac157> in <module>
#       5 from datetime import timedelta
#       6 import sqlite3
# ----> 7 from src.datacleaning.create_df import load_df, impelement_column_creation
#       8 from src.datacleaning.columns_from_hand_history import fill_HH_columns
#       9 from src.datacleaning.time_columns import fill_time_columns
#
# ~/Documents/DSI/capstone/poker/src/datacleaning/create_df.py in <module>
#       1 import pandas as pd
#       2 import sqlite3
# ----> 3 from columns_from_hand_history import fill_HH_columns
#       4 from time_columns import fill_time_columns
#       5 from dependent_columns import fill_dependent_columns
#
# ModuleNotFoundError: No module named 'columns_from_hand_history'

# %%
df_full = pd.read_csv('src/datacleaning/playing_around.csv')

# %%
def prior_actions_for_stats(df, disclude_cash=True):
    '''
    finds actions of player prior to the hand currently being played 
    '''
    if disclude_cash:    
        mask = df['TournamentNumber'] != '' # ignores cash hands for time being 
        df = df[mask]
        
    total_dic = {} # probably replace this w/ assignment directly to the dataframe 
    unique_TN = df['TournamentNumber'].unique()
    for num in unique_TN: # iterates through all unique tournament numbers
        mask = df['TournamentNumber'] == num
        tourn_df = df[mask]
        for idx, row in tourn_df.iterrows(): # go through each row of tournament 
            row_dic = {}
            mask = tourn_df.index < idx
            df_prior = tourn_df[mask] # hands that occured previously in this tournament 
            for player in row['player_names']: # looping through all players present in hand
                player_actions = []
                for dic in df_prior['action_type']: # looking at all prior hands 
                    if player in dic:
                        player_actions.append(dic[player])
                row_dic[player] = player_actions
            total_dic[idx] = row_dic
    return total_dic

# %%
prior_actions_for_stats(df_full)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-4124d5951659> in <module>
# ----> 1 prior_actions_for_stats(df_full)
#
# <ipython-input-3-906768b5a286> in prior_actions_for_stats(df, disclude_cash)
#      20                 for dic in df_prior['action_type']: # looking at all prior hands
#      21                     if player in dic:
# ---> 22                         player_actions.append(dic[player])
#      23                 row_dic[player] = player_actions
#      24             total_dic[idx] = row_dic
#
# TypeError: string indices must be integers

# %%
df_full
# Out:
#        Unnamed: 0  HandHistoryId  HandNumber  PokerSiteId  \
# 0               0              1  3951210633            1
# 1               1              2  3951211988            1
# 2               2              3  3951212830            1
# 3               3              4  3951214131            1
# 4               4              5  3951215154            1
# ...           ...            ...         ...          ...
# 54299       54299          54333  4286799273            1
# 54300       54300          54334  4286799339            1
# 54301       54301          54335  4286799383            1
# 54302       54302          54336  4286799396            1
# 54303       54303          54337  4286799413            1
#
#                                              HandHistory HandHistoryTimestamp  \
# 0      ['<session sessioncode="459742">', '<general>'...  2019-10-23 21:08:08
# 1      ['<session sessioncode="459742">', '<general>'...  2019-10-23 21:09:34
# 2      ['<session sessioncode="459742">', '<general>'...  2019-10-23 21:11:47
# 3      ['<session sessioncode="459742">', '<general>'...  2019-10-23 21:13:37
# 4      ['<session sessioncode="459742">', '<general>'...  2019-10-23 21:14:31
# ...                                                  ...                  ...
# 54299  ['<session sessioncode="3408296">', '<general>...  2021-03-30 08:12:25
# 54300  ['<session sessioncode="4917292">', '<general>...  2021-03-30 08:12:29
# 54301  ['<session sessioncode="3408296">', '<general>...  2021-03-30 08:12:34
# 54302  ['<session sessioncode="4917292">', '<general>...  2021-03-30 08:12:41
# 54303  ['<session sessioncode="3408296">', '<general>...  2021-03-30 08:12:50
#
#        GameType  TournamentNumber  buyin cash_or_tourn  my_blind_anti_total  \
# 0             1          459742.0   1.10     Holdem NL                 20.0
# 1             1          459742.0   1.10     Holdem NL                 10.0
# 2             1          459742.0   1.10     Holdem NL                  0.0
# 3             1          459742.0   1.10     Holdem NL                  0.0
# 4             1          459742.0   1.10     Holdem NL                  0.0
# ...         ...               ...    ...           ...                  ...
# 54299        82        41343764.0   5.25     Holdem NL                200.0
# 54300        82        41343587.0   5.25     Holdem NL                100.0
# 54301        82        41343764.0   5.25     Holdem NL                100.0
# 54302       112        41343587.0   5.25     Holdem NL                 96.0
# 54303        82        41343764.0   5.25     Holdem NL                200.0
#
#            my_cards  starting_stack          tournament_type    won     bet  \
# 0      ['C5', 'H2']          1500.0         3-Table Sit & Go    0.0    20.0
# 1      ['C9', 'S9']          1480.0         3-Table Sit & Go  640.0   420.0
# 2      ['S3', 'DK']          1700.0         3-Table Sit & Go    0.0     0.0
# 3      ['C9', 'D8']          1700.0         3-Table Sit & Go    0.0     0.0
# 4      ['S7', 'HQ']          1700.0         3-Table Sit & Go    0.0     0.0
# ...             ...             ...                      ...    ...     ...
# 54299  ['HA', 'H3']          1850.0  Hyper Turbo (500 Chips)  700.0  1850.0
# 54300  ['D6', 'H4']           196.0  Hyper Turbo (500 Chips)    0.0   100.0
# 54301  ['C8', 'H6']           700.0  Hyper Turbo (500 Chips)    0.0   100.0
# 54302  ['DA', 'H7']            96.0  Hyper Turbo (500 Chips)    0.0    96.0
# 54303  ['SQ', 'S1']           600.0  Hyper Turbo (500 Chips)    0.0   600.0
#
#        total_players  position  table_max_players  \
# 0                  9  0.222222                  9
# 1                  9  0.111111                  9
# 2                  9  1.000000                  9
# 3                  8  0.875000                  9
# 4                  8  0.750000                  9
# ...              ...       ...                ...
# 54299              2  0.500000                  6
# 54300              2  1.000000                  6
# 54301              2  1.000000                  6
# 54302              2  0.500000                  6
# 54303              2  0.500000                  6
#
#        bets_before_my_preflop_action  \
# 0                               80.0
# 1                               40.0
# 2                              200.0
# 3                                0.0
# 4                                0.0
# ...                              ...
# 54299                          100.0
# 54300                            0.0
# 54301                            0.0
# 54302                            0.0
# 54303                          400.0
#
#                                              action_type  \
# 0      {'P26_251842VD': 3, 'P4_131206CX': 0, 'P11_924...
# 1      {'P4_131206CX': 0, 'P11_924370QJ': 0, 'P18_572...
# 2      {'P11_924370QJ': 0, 'P18_572249IY': 0, 'P14_45...
# 3      {'P18_572249IY': 0, 'P25_871309MO': 0, 'P3_286...
# 4      {'P25_871309MO': 0, 'P3_286963JX': 0, 'P5_4057...
# ...                                                  ...
# 54299                      {'P6_773472PB': 3, 'Hero': 7}
# 54300                                        {'Hero': 0}
# 54301                                        {'Hero': 0}
# 54302                                                 {}
# 54303                     {'P6_773472PB': 23, 'Hero': 7}
#
#                                             player_names  hour  \
# 0      ['P18_572249IY', 'P14_459713MR', 'P25_871309MO...    21
# 1      ['P18_572249IY', 'P14_459713MR', 'P25_871309MO...    21
# 2      ['P18_572249IY', 'P14_459713MR', 'P25_871309MO...    21
# 3      ['P18_572249IY', 'P25_871309MO', 'P3_286963JX'...    21
# 4      ['P18_572249IY', 'P25_871309MO', 'P3_286963JX'...    21
# ...                                                  ...   ...
# 54299                            ['P6_773472PB', 'Hero']     8
# 54300                            ['P1_574120EG', 'Hero']     8
# 54301                            ['P6_773472PB', 'Hero']     8
# 54302                            ['P1_574120EG', 'Hero']     8
# 54303                            ['P6_773472PB', 'Hero']     8
#
#             year_month_day  days_since_start  hand_frequency          blinds  \
# 0      2019-10-23 00:00:00                 0            2155    [10.0, 20.0]
# 1      2019-10-23 00:00:00                 0            2155    [10.0, 20.0]
# 2      2019-10-23 00:00:00                 0            2155    [10.0, 20.0]
# 3      2019-10-23 00:00:00                 0            2155    [10.0, 20.0]
# 4      2019-10-23 00:00:00                 0            2155    [10.0, 20.0]
# ...                    ...               ...             ...             ...
# 54299  2021-03-30 00:00:00               524             699  [100.0, 200.0]
# 54300  2021-03-30 00:00:00               524             699  [100.0, 200.0]
# 54301  2021-03-30 00:00:00               524             699  [100.0, 200.0]
# 54302  2021-03-30 00:00:00               524             699   [100.0, 96.0]
# 54303  2021-03-30 00:00:00               524             699  [100.0, 200.0]
#
#        made_money  card_rank     BB  BB_in_stack  net_outcome  all_in  \
# 0               0        0.5   20.0        75.00        -20.0     0.0
# 1               1        9.0   20.0        74.00        220.0     0.0
# 2               0        3.0   20.0        85.00          0.0     0.0
# 3               0        5.5   20.0        85.00          0.0     0.0
# 4               0        2.0   20.0        85.00          0.0     0.0
# ...           ...        ...    ...          ...          ...     ...
# 54299           0        7.0  200.0         9.25      -1150.0     1.0
# 54300           0        3.0  200.0         0.98       -100.0     0.0
# 54301           0        4.0  200.0         3.50       -100.0     0.0
# 54302           0        5.0    NaN          NaN        -96.0     1.0
# 54303           0        8.0  200.0         3.00       -600.0     1.0
#
#        money_beyond_blind  outcome_relative_to_start  made_or_lost  flop_bet  \
# 0                       0                   0.986667             0       0.0
# 1                       1                   1.148649             1     320.0
# 2                       0                   1.000000             1       0.0
# 3                       0                   1.000000             1       0.0
# 4                       0                   1.000000             1       0.0
# ...                   ...                        ...           ...       ...
# 54299                   1                   0.378378             0       0.0
# 54300                   0                   0.489796             0       0.0
# 54301                   0                   0.857143             0       0.0
# 54302                   0                   0.000000             0       0.0
# 54303                   1                   0.000000             0       0.0
#
#        turn_bet  river_bet  preflop_bet  high_card  low_card  suited  \
# 0           0.0        0.0          0.0        5.0       2.0       0
# 1           0.0        0.0         90.0        9.0       9.0       0
# 2           0.0        0.0          0.0       13.0       3.0       0
# 3           0.0        0.0          0.0        9.0       8.0       0
# 4           0.0        0.0          0.0       12.0       7.0       0
# ...         ...        ...          ...        ...       ...     ...
# 54299       0.0        0.0       1650.0       14.0       3.0       1
# 54300       0.0        0.0          0.0        6.0       4.0       0
# 54301       0.0        0.0          0.0        8.0       6.0       0
# 54302       0.0        0.0          0.0       14.0       7.0       0
# 54303       0.0        0.0        400.0       12.0      10.0       1
#
#        pocket_pair   gap
# 0                0   3.0
# 1                1   0.0
# 2                0  10.0
# 3                0   1.0
# 4                0   5.0
# ...            ...   ...
# 54299            0  11.0
# 54300            0   2.0
# 54301            0   2.0
# 54302            0   7.0
# 54303            0   2.0
#
# [54304 rows x 45 columns]
