# %%
import pandas as pd 
pd.set_option('display.max_rows', 500)

# %%
results = pd.read_csv('../data/compare_models_features/classification_model_comparison_limps_calls_reraises.csv')
results_2 = pd.read_csv('../data/compare_models_features/classification_model_comparison_num_players_.csv')
results_3 = pd.read_csv('../data/compare_models_features/classification_model_table_stats.csv')
results_4 = pd.read_csv('../data/compare_models_features/classification_model_relevant_stats.csv')
results_5 = pd.read_csv('../data/compare_models_features/classification_model_compare_talbe_revelvant.csv')
results_6 = pd.read_csv('../data/compare_models_features/classification_model_compare_removed_columns.csv')
results_7 = pd.read_csv('../data/compare_models_features/classification_model_compare_XGB.csv')
results_8 = pd.read_csv('../data/compare_models_features/classification_compare_card_features.csv')
results_9 = pd.read_csv('../data/compare_models_features/classification_compare_card_features_round2.csv')
results_10 = pd.read_csv('../data/compare_models_features/classification_compare_card_features_round3.csv')
results_11 = pd.read_csv('../data/classification_compare_card_features_weighted_vpip.csv')
results_12 = pd.read_csv('../data/classification_compare_card_features_limpers&callers.csv')
results_13 = pd.read_csv('../data/classification_compare_card_features_limpers&callers.csv)

# %%
results_12.sort_values('roc_auc', ascending=False)
# Out:
#     Unnamed: 0          model                                columns  \
# 14          14  GradientBoost             ['callers', 'limps&calls']
# 8            8  GradientBoost                                     []
# 15          15  GradientBoost  ['limpers', 'callers', 'limps&calls']
# 13          13  GradientBoost             ['limpers', 'limps&calls']
# 10          10  GradientBoost                            ['callers']
# 11          11  GradientBoost                        ['limps&calls']
# 9            9  GradientBoost                            ['limpers']
# 12          12  GradientBoost                 ['limpers', 'callers']
# 21          21       AdaBoost             ['limpers', 'limps&calls']
# 19          19       AdaBoost                        ['limps&calls']
# 16          16       AdaBoost                                     []
# 17          17       AdaBoost                            ['limpers']
# 18          18       AdaBoost                            ['callers']
# 20          20       AdaBoost                 ['limpers', 'callers']
# 22          22       AdaBoost             ['callers', 'limps&calls']
# 23          23       AdaBoost  ['limpers', 'callers', 'limps&calls']
# 32          32       logistic                                     []
# 33          33       logistic                            ['limpers']
# 34          34       logistic                            ['callers']
# 35          35       logistic                        ['limps&calls']
# 37          37       logistic             ['limpers', 'limps&calls']
# 36          36       logistic                 ['limpers', 'callers']
# 38          38       logistic             ['callers', 'limps&calls']
# 39          39       logistic  ['limpers', 'callers', 'limps&calls']
# 4            4   RandomForest                 ['limpers', 'callers']
# 0            0   RandomForest                                     []
# 5            5   RandomForest             ['limpers', 'limps&calls']
# 7            7   RandomForest  ['limpers', 'callers', 'limps&calls']
# 2            2   RandomForest                            ['callers']
# 3            3   RandomForest                        ['limps&calls']
# 1            1   RandomForest                            ['limpers']
# 6            6   RandomForest             ['callers', 'limps&calls']
# 27          27            KNN                        ['limps&calls']
# 29          29            KNN             ['limpers', 'limps&calls']
# 25          25            KNN                            ['limpers']
# 31          31            KNN  ['limpers', 'callers', 'limps&calls']
# 28          28            KNN                 ['limpers', 'callers']
# 30          30            KNN             ['callers', 'limps&calls']
# 26          26            KNN                            ['callers']
# 24          24            KNN                                     []
#
#        brier   roc_auc
# 14  0.212676  0.694696
# 8   0.212494  0.694220
# 15  0.212800  0.693944
# 13  0.212652  0.693875
# 10  0.212820  0.693846
# 11  0.212749  0.693727
# 9   0.212820  0.693501
# 12  0.212994  0.693112
# 21  0.248370  0.686832
# 19  0.248364  0.686830
# 16  0.248353  0.686812
# 17  0.248357  0.686798
# 18  0.248362  0.686661
# 20  0.248365  0.686647
# 22  0.248356  0.686574
# 23  0.248361  0.686492
# 32  0.218548  0.674623
# 33  0.218621  0.674508
# 34  0.218744  0.674314
# 35  0.218603  0.674234
# 37  0.218781  0.673988
# 36  0.218791  0.673972
# 38  0.218791  0.673968
# 39  0.218792  0.673960
# 4   0.242732  0.639903
# 0   0.240772  0.639862
# 5   0.242757  0.638084
# 7   0.242587  0.637780
# 2   0.240469  0.637630
# 3   0.241623  0.637527
# 1   0.241643  0.637463
# 6   0.242326  0.636815
# 27  0.251613  0.630373
# 29  0.251627  0.630261
# 25  0.251473  0.630204
# 31  0.251842  0.629801
# 28  0.251940  0.629506
# 30  0.251945  0.629498
# 26  0.251777  0.629497
# 24  0.251674  0.629481

# %%
results_12.sort_values('brier')
# Out:
#     Unnamed: 0          model                                columns  \
# 8            8  GradientBoost                                     []
# 13          13  GradientBoost             ['limpers', 'limps&calls']
# 14          14  GradientBoost             ['callers', 'limps&calls']
# 11          11  GradientBoost                        ['limps&calls']
# 15          15  GradientBoost  ['limpers', 'callers', 'limps&calls']
# 9            9  GradientBoost                            ['limpers']
# 10          10  GradientBoost                            ['callers']
# 12          12  GradientBoost                 ['limpers', 'callers']
# 32          32       logistic                                     []
# 35          35       logistic                        ['limps&calls']
# 33          33       logistic                            ['limpers']
# 34          34       logistic                            ['callers']
# 37          37       logistic             ['limpers', 'limps&calls']
# 36          36       logistic                 ['limpers', 'callers']
# 38          38       logistic             ['callers', 'limps&calls']
# 39          39       logistic  ['limpers', 'callers', 'limps&calls']
# 2            2   RandomForest                            ['callers']
# 0            0   RandomForest                                     []
# 3            3   RandomForest                        ['limps&calls']
# 1            1   RandomForest                            ['limpers']
# 6            6   RandomForest             ['callers', 'limps&calls']
# 7            7   RandomForest  ['limpers', 'callers', 'limps&calls']
# 4            4   RandomForest                 ['limpers', 'callers']
# 5            5   RandomForest             ['limpers', 'limps&calls']
# 16          16       AdaBoost                                     []
# 22          22       AdaBoost             ['callers', 'limps&calls']
# 17          17       AdaBoost                            ['limpers']
# 23          23       AdaBoost  ['limpers', 'callers', 'limps&calls']
# 18          18       AdaBoost                            ['callers']
# 19          19       AdaBoost                        ['limps&calls']
# 20          20       AdaBoost                 ['limpers', 'callers']
# 21          21       AdaBoost             ['limpers', 'limps&calls']
# 25          25            KNN                            ['limpers']
# 27          27            KNN                        ['limps&calls']
# 29          29            KNN             ['limpers', 'limps&calls']
# 24          24            KNN                                     []
# 26          26            KNN                            ['callers']
# 31          31            KNN  ['limpers', 'callers', 'limps&calls']
# 28          28            KNN                 ['limpers', 'callers']
# 30          30            KNN             ['callers', 'limps&calls']
#
#        brier   roc_auc
# 8   0.212494  0.694220
# 13  0.212652  0.693875
# 14  0.212676  0.694696
# 11  0.212749  0.693727
# 15  0.212800  0.693944
# 9   0.212820  0.693501
# 10  0.212820  0.693846
# 12  0.212994  0.693112
# 32  0.218548  0.674623
# 35  0.218603  0.674234
# 33  0.218621  0.674508
# 34  0.218744  0.674314
# 37  0.218781  0.673988
# 36  0.218791  0.673972
# 38  0.218791  0.673968
# 39  0.218792  0.673960
# 2   0.240469  0.637630
# 0   0.240772  0.639862
# 3   0.241623  0.637527
# 1   0.241643  0.637463
# 6   0.242326  0.636815
# 7   0.242587  0.637780
# 4   0.242732  0.639903
# 5   0.242757  0.638084
# 16  0.248353  0.686812
# 22  0.248356  0.686574
# 17  0.248357  0.686798
# 23  0.248361  0.686492
# 18  0.248362  0.686661
# 19  0.248364  0.686830
# 20  0.248365  0.686647
# 21  0.248370  0.686832
# 25  0.251473  0.630204
# 27  0.251613  0.630373
# 29  0.251627  0.630261
# 24  0.251674  0.629481
# 26  0.251777  0.629497
# 31  0.251842  0.629801
# 28  0.251940  0.629506
# 30  0.251945  0.629498

# %%
results_2.sort_values('roc_auc', ascending=False)
# Out:
#     Unnamed: 0          model  \
# 15          15  GradientBoost
# 12          12  GradientBoost
# 13          13  GradientBoost
# 14          14  GradientBoost
# 10          10  GradientBoost
# 11          11  GradientBoost
# 23          23       AdaBoost
# 22          22       AdaBoost
# 20          20       AdaBoost
# 21          21       AdaBoost
# 9            9  GradientBoost
# 19          19       AdaBoost
# 18          18       AdaBoost
# 8            8  GradientBoost
# 17          17       AdaBoost
# 36          36       logistic
# 16          16       AdaBoost
# 39          39       logistic
# 34          34       logistic
# 38          38       logistic
# 33          33       logistic
# 37          37       logistic
# 32          32       logistic
# 35          35       logistic
# 4            4   RandomForest
# 5            5   RandomForest
# 6            6   RandomForest
# 3            3   RandomForest
# 7            7   RandomForest
# 1            1   RandomForest
# 0            0   RandomForest
# 2            2   RandomForest
# 31          31            KNN
# 30          30            KNN
# 28          28            KNN
# 26          26            KNN
# 29          29            KNN
# 27          27            KNN
# 25          25            KNN
# 24          24            KNN
#
#                                               columns     brier   roc_auc
# 15  ['num_players_before', 'num_players_after', 'a...  0.214435  0.687146
# 12        ['num_players_before', 'num_players_after']  0.214677  0.686089
# 13           ['num_players_before', 'amount_to_call']  0.214750  0.685979
# 14            ['num_players_after', 'amount_to_call']  0.215507  0.683039
# 10                              ['num_players_after']  0.215783  0.682610
# 11                                 ['amount_to_call']  0.215656  0.682308
# 23  ['num_players_before', 'num_players_after', 'a...  0.248347  0.681601
# 22            ['num_players_after', 'amount_to_call']  0.248403  0.681124
# 20        ['num_players_before', 'num_players_after']  0.248397  0.680630
# 21           ['num_players_before', 'amount_to_call']  0.248364  0.680571
# 9                              ['num_players_before']  0.216202  0.680246
# 19                                 ['amount_to_call']  0.248374  0.679090
# 18                              ['num_players_after']  0.248440  0.677860
# 8                                                  []  0.217004  0.677259
# 17                             ['num_players_before']  0.248471  0.670425
# 36        ['num_players_before', 'num_players_after']  0.219346  0.669982
# 16                                                 []  0.248498  0.669673
# 39  ['num_players_before', 'num_players_after', 'a...  0.219431  0.669608
# 34                              ['num_players_after']  0.219868  0.668265
# 38            ['num_players_after', 'amount_to_call']  0.219908  0.667964
# 33                             ['num_players_before']  0.221467  0.659617
# 37           ['num_players_before', 'amount_to_call']  0.221567  0.659199
# 32                                                 []  0.221669  0.659046
# 35                                 ['amount_to_call']  0.221747  0.658669
# 4         ['num_players_before', 'num_players_after']  0.233219  0.646363
# 5            ['num_players_before', 'amount_to_call']  0.231373  0.646267
# 6             ['num_players_after', 'amount_to_call']  0.233336  0.645868
# 3                                  ['amount_to_call']  0.233193  0.643714
# 7   ['num_players_before', 'num_players_after', 'a...  0.233058  0.643287
# 1                              ['num_players_before']  0.234073  0.642147
# 0                                                  []  0.234866  0.639660
# 2                               ['num_players_after']  0.233156  0.638683
# 31  ['num_players_before', 'num_players_after', 'a...  0.251367  0.625043
# 30            ['num_players_after', 'amount_to_call']  0.251873  0.623180
# 28        ['num_players_before', 'num_players_after']  0.252370  0.622660
# 26                              ['num_players_after']  0.252735  0.621319
# 29           ['num_players_before', 'amount_to_call']  0.252681  0.621074
# 27                                 ['amount_to_call']  0.253027  0.619658
# 25                             ['num_players_before']  0.253518  0.618839
# 24                                                 []  0.253187  0.618578

# %%
results_2.sort_values('brier')
# Out:
#     Unnamed: 0          model  \
# 15          15  GradientBoost
# 12          12  GradientBoost
# 13          13  GradientBoost
# 14          14  GradientBoost
# 11          11  GradientBoost
# 10          10  GradientBoost
# 9            9  GradientBoost
# 8            8  GradientBoost
# 36          36       logistic
# 39          39       logistic
# 34          34       logistic
# 38          38       logistic
# 33          33       logistic
# 37          37       logistic
# 32          32       logistic
# 35          35       logistic
# 5            5   RandomForest
# 7            7   RandomForest
# 2            2   RandomForest
# 3            3   RandomForest
# 4            4   RandomForest
# 6            6   RandomForest
# 1            1   RandomForest
# 0            0   RandomForest
# 23          23       AdaBoost
# 21          21       AdaBoost
# 19          19       AdaBoost
# 20          20       AdaBoost
# 22          22       AdaBoost
# 18          18       AdaBoost
# 17          17       AdaBoost
# 16          16       AdaBoost
# 31          31            KNN
# 30          30            KNN
# 28          28            KNN
# 29          29            KNN
# 26          26            KNN
# 27          27            KNN
# 24          24            KNN
# 25          25            KNN
#
#                                               columns     brier   roc_auc
# 15  ['num_players_before', 'num_players_after', 'a...  0.214435  0.687146
# 12        ['num_players_before', 'num_players_after']  0.214677  0.686089
# 13           ['num_players_before', 'amount_to_call']  0.214750  0.685979
# 14            ['num_players_after', 'amount_to_call']  0.215507  0.683039
# 11                                 ['amount_to_call']  0.215656  0.682308
# 10                              ['num_players_after']  0.215783  0.682610
# 9                              ['num_players_before']  0.216202  0.680246
# 8                                                  []  0.217004  0.677259
# 36        ['num_players_before', 'num_players_after']  0.219346  0.669982
# 39  ['num_players_before', 'num_players_after', 'a...  0.219431  0.669608
# 34                              ['num_players_after']  0.219868  0.668265
# 38            ['num_players_after', 'amount_to_call']  0.219908  0.667964
# 33                             ['num_players_before']  0.221467  0.659617
# 37           ['num_players_before', 'amount_to_call']  0.221567  0.659199
# 32                                                 []  0.221669  0.659046
# 35                                 ['amount_to_call']  0.221747  0.658669
# 5            ['num_players_before', 'amount_to_call']  0.231373  0.646267
# 7   ['num_players_before', 'num_players_after', 'a...  0.233058  0.643287
# 2                               ['num_players_after']  0.233156  0.638683
# 3                                  ['amount_to_call']  0.233193  0.643714
# 4         ['num_players_before', 'num_players_after']  0.233219  0.646363
# 6             ['num_players_after', 'amount_to_call']  0.233336  0.645868
# 1                              ['num_players_before']  0.234073  0.642147
# 0                                                  []  0.234866  0.639660
# 23  ['num_players_before', 'num_players_after', 'a...  0.248347  0.681601
# 21           ['num_players_before', 'amount_to_call']  0.248364  0.680571
# 19                                 ['amount_to_call']  0.248374  0.679090
# 20        ['num_players_before', 'num_players_after']  0.248397  0.680630
# 22            ['num_players_after', 'amount_to_call']  0.248403  0.681124
# 18                              ['num_players_after']  0.248440  0.677860
# 17                             ['num_players_before']  0.248471  0.670425
# 16                                                 []  0.248498  0.669673
# 31  ['num_players_before', 'num_players_after', 'a...  0.251367  0.625043
# 30            ['num_players_after', 'amount_to_call']  0.251873  0.623180
# 28        ['num_players_before', 'num_players_after']  0.252370  0.622660
# 29           ['num_players_before', 'amount_to_call']  0.252681  0.621074
# 26                              ['num_players_after']  0.252735  0.621319
# 27                                 ['amount_to_call']  0.253027  0.619658
# 24                                                 []  0.253187  0.618578
# 25                             ['num_players_before']  0.253518  0.618839

# %%
results_3.sort_values('roc_auc', ascending=False)
# Out:
#     Unnamed: 0          model  \
# 6            6  GradientBoost
# 4            4  GradientBoost
# 7            7  GradientBoost
# 5            5  GradientBoost
# 9            9       AdaBoost
# 8            8       AdaBoost
# 11          11       AdaBoost
# 10          10       AdaBoost
# 19          19       logistic
# 18          18       logistic
# 17          17       logistic
# 16          16       logistic
# 3            3   RandomForest
# 1            1   RandomForest
# 2            2   RandomForest
# 0            0   RandomForest
# 12          12            KNN
# 13          13            KNN
# 14          14            KNN
# 15          15            KNN
#
#                                               columns     brier   roc_auc
# 6                         ['total_actions_witnessed']  0.214261  0.687850
# 4                                                  []  0.214672  0.686104
# 7   ['average_table_vpip', 'total_actions_witnessed']  0.215069  0.684893
# 5                              ['average_table_vpip']  0.215229  0.684698
# 9                              ['average_table_vpip']  0.248371  0.680744
# 8                                                  []  0.248397  0.680630
# 11  ['average_table_vpip', 'total_actions_witnessed']  0.248386  0.680145
# 10                        ['total_actions_witnessed']  0.248455  0.678609
# 19  ['average_table_vpip', 'total_actions_witnessed']  0.218724  0.672864
# 18                        ['total_actions_witnessed']  0.218866  0.671943
# 17                             ['average_table_vpip']  0.219074  0.671372
# 16                                                 []  0.219346  0.669982
# 3   ['average_table_vpip', 'total_actions_witnessed']  0.225527  0.656436
# 1                              ['average_table_vpip']  0.225188  0.653032
# 2                         ['total_actions_witnessed']  0.227763  0.651410
# 0                                                  []  0.233305  0.645001
# 12                                                 []  0.252370  0.622660
# 13                             ['average_table_vpip']  0.250681  0.622297
# 14                        ['total_actions_witnessed']  0.252749  0.620081
# 15  ['average_table_vpip', 'total_actions_witnessed']  0.254954  0.613454

# %%
results_3.sort_values('brier')
# Out:
#     Unnamed: 0          model  \
# 6            6  GradientBoost
# 4            4  GradientBoost
# 7            7  GradientBoost
# 5            5  GradientBoost
# 19          19       logistic
# 18          18       logistic
# 17          17       logistic
# 16          16       logistic
# 1            1   RandomForest
# 3            3   RandomForest
# 2            2   RandomForest
# 0            0   RandomForest
# 9            9       AdaBoost
# 11          11       AdaBoost
# 8            8       AdaBoost
# 10          10       AdaBoost
# 13          13            KNN
# 12          12            KNN
# 14          14            KNN
# 15          15            KNN
#
#                                               columns     brier   roc_auc
# 6                         ['total_actions_witnessed']  0.214261  0.687850
# 4                                                  []  0.214672  0.686104
# 7   ['average_table_vpip', 'total_actions_witnessed']  0.215069  0.684893
# 5                              ['average_table_vpip']  0.215229  0.684698
# 19  ['average_table_vpip', 'total_actions_witnessed']  0.218724  0.672864
# 18                        ['total_actions_witnessed']  0.218866  0.671943
# 17                             ['average_table_vpip']  0.219074  0.671372
# 16                                                 []  0.219346  0.669982
# 1                              ['average_table_vpip']  0.225188  0.653032
# 3   ['average_table_vpip', 'total_actions_witnessed']  0.225527  0.656436
# 2                         ['total_actions_witnessed']  0.227763  0.651410
# 0                                                  []  0.233305  0.645001
# 9                              ['average_table_vpip']  0.248371  0.680744
# 11  ['average_table_vpip', 'total_actions_witnessed']  0.248386  0.680145
# 8                                                  []  0.248397  0.680630
# 10                        ['total_actions_witnessed']  0.248455  0.678609
# 13                             ['average_table_vpip']  0.250681  0.622297
# 12                                                 []  0.252370  0.622660
# 14                        ['total_actions_witnessed']  0.252749  0.620081
# 15  ['average_table_vpip', 'total_actions_witnessed']  0.254954  0.613454

# %%
results_4.sort_values('roc_auc', ascending=False)
# Out:
#     Unnamed: 0          model  \
# 7            7  GradientBoost
# 6            6  GradientBoost
# 4            4  GradientBoost
# 5            5  GradientBoost
# 11          11       AdaBoost
# 10          10       AdaBoost
# 9            9       AdaBoost
# 8            8       AdaBoost
# 19          19       logistic
# 18          18       logistic
# 17          17       logistic
# 16          16       logistic
# 1            1   RandomForest
# 3            3   RandomForest
# 2            2   RandomForest
# 0            0   RandomForest
# 13          13            KNN
# 12          12            KNN
# 15          15            KNN
# 14          14            KNN
#
#                                               columns     brier   roc_auc
# 7   ['vpip_relavant_players', 'total_actions_witne...  0.213822  0.690510
# 6        ['total_actions_witnessed_relevant_players']  0.213656  0.690292
# 4                                                  []  0.214683  0.686146
# 5                           ['vpip_relavant_players']  0.214954  0.685614
# 11  ['vpip_relavant_players', 'total_actions_witne...  0.248339  0.684883
# 10       ['total_actions_witnessed_relevant_players']  0.248409  0.683044
# 9                           ['vpip_relavant_players']  0.248376  0.681307
# 8                                                  []  0.248397  0.680630
# 19  ['vpip_relavant_players', 'total_actions_witne...  0.218547  0.673905
# 18       ['total_actions_witnessed_relevant_players']  0.218795  0.672506
# 17                          ['vpip_relavant_players']  0.218960  0.672071
# 16                                                 []  0.219346  0.669982
# 1                           ['vpip_relavant_players']  0.224660  0.664625
# 3   ['vpip_relavant_players', 'total_actions_witne...  0.221844  0.663138
# 2        ['total_actions_witnessed_relevant_players']  0.228007  0.648533
# 0                                                  []  0.233885  0.644512
# 13                          ['vpip_relavant_players']  0.251241  0.625229
# 12                                                 []  0.252370  0.622660
# 15  ['vpip_relavant_players', 'total_actions_witne...  0.252915  0.620769
# 14       ['total_actions_witnessed_relevant_players']  0.254029  0.619025

# %%
results_4.sort_values('brier')
# Out:
#     Unnamed: 0          model  \
# 6            6  GradientBoost
# 7            7  GradientBoost
# 4            4  GradientBoost
# 5            5  GradientBoost
# 19          19       logistic
# 18          18       logistic
# 17          17       logistic
# 16          16       logistic
# 3            3   RandomForest
# 1            1   RandomForest
# 2            2   RandomForest
# 0            0   RandomForest
# 11          11       AdaBoost
# 9            9       AdaBoost
# 8            8       AdaBoost
# 10          10       AdaBoost
# 13          13            KNN
# 12          12            KNN
# 15          15            KNN
# 14          14            KNN
#
#                                               columns     brier   roc_auc
# 6        ['total_actions_witnessed_relevant_players']  0.213656  0.690292
# 7   ['vpip_relavant_players', 'total_actions_witne...  0.213822  0.690510
# 4                                                  []  0.214683  0.686146
# 5                           ['vpip_relavant_players']  0.214954  0.685614
# 19  ['vpip_relavant_players', 'total_actions_witne...  0.218547  0.673905
# 18       ['total_actions_witnessed_relevant_players']  0.218795  0.672506
# 17                          ['vpip_relavant_players']  0.218960  0.672071
# 16                                                 []  0.219346  0.669982
# 3   ['vpip_relavant_players', 'total_actions_witne...  0.221844  0.663138
# 1                           ['vpip_relavant_players']  0.224660  0.664625
# 2        ['total_actions_witnessed_relevant_players']  0.228007  0.648533
# 0                                                  []  0.233885  0.644512
# 11  ['vpip_relavant_players', 'total_actions_witne...  0.248339  0.684883
# 9                           ['vpip_relavant_players']  0.248376  0.681307
# 8                                                  []  0.248397  0.680630
# 10       ['total_actions_witnessed_relevant_players']  0.248409  0.683044
# 13                          ['vpip_relavant_players']  0.251241  0.625229
# 12                                                 []  0.252370  0.622660
# 15  ['vpip_relavant_players', 'total_actions_witne...  0.252915  0.620769
# 14       ['total_actions_witnessed_relevant_players']  0.254029  0.619025

# %%
results_5.sort_values('roc_auc', ascending=False)
# Out:
#     Unnamed: 0          model  \
# 4            4  GradientBoost
# 3            3  GradientBoost
# 5            5  GradientBoost
# 7            7       AdaBoost
# 6            6       AdaBoost
# 8            8       AdaBoost
# 13          13       logistic
# 14          14       logistic
# 12          12       logistic
# 1            1   RandomForest
# 2            2   RandomForest
# 0            0   RandomForest
# 9            9            KNN
# 10          10            KNN
# 11          11            KNN
#
#                                               columns     brier   roc_auc
# 4   ['vpip_relavant_players', 'total_actions_witne...  0.213797  0.690397
# 3                                                  []  0.214699  0.686187
# 5   ['average_table_vpip', 'total_actions_witnessed']  0.214963  0.685030
# 7   ['vpip_relavant_players', 'total_actions_witne...  0.248339  0.684883
# 6                                                  []  0.248397  0.680630
# 8   ['average_table_vpip', 'total_actions_witnessed']  0.248386  0.680145
# 13  ['vpip_relavant_players', 'total_actions_witne...  0.218547  0.673905
# 14  ['average_table_vpip', 'total_actions_witnessed']  0.218724  0.672864
# 12                                                 []  0.219346  0.669982
# 1   ['vpip_relavant_players', 'total_actions_witne...  0.222640  0.662759
# 2   ['average_table_vpip', 'total_actions_witnessed']  0.223881  0.655159
# 0                                                  []  0.233524  0.641839
# 9                                                  []  0.252370  0.622660
# 10  ['vpip_relavant_players', 'total_actions_witne...  0.252915  0.620769
# 11  ['average_table_vpip', 'total_actions_witnessed']  0.254954  0.613454

# %%
results_5.sort_values('brier')
# Out:
#     Unnamed: 0          model  \
# 4            4  GradientBoost
# 3            3  GradientBoost
# 5            5  GradientBoost
# 13          13       logistic
# 14          14       logistic
# 12          12       logistic
# 1            1   RandomForest
# 2            2   RandomForest
# 0            0   RandomForest
# 7            7       AdaBoost
# 8            8       AdaBoost
# 6            6       AdaBoost
# 9            9            KNN
# 10          10            KNN
# 11          11            KNN
#
#                                               columns     brier   roc_auc
# 4   ['vpip_relavant_players', 'total_actions_witne...  0.213797  0.690397
# 3                                                  []  0.214699  0.686187
# 5   ['average_table_vpip', 'total_actions_witnessed']  0.214963  0.685030
# 13  ['vpip_relavant_players', 'total_actions_witne...  0.218547  0.673905
# 14  ['average_table_vpip', 'total_actions_witnessed']  0.218724  0.672864
# 12                                                 []  0.219346  0.669982
# 1   ['vpip_relavant_players', 'total_actions_witne...  0.222640  0.662759
# 2   ['average_table_vpip', 'total_actions_witnessed']  0.223881  0.655159
# 0                                                  []  0.233524  0.641839
# 7   ['vpip_relavant_players', 'total_actions_witne...  0.248339  0.684883
# 8   ['average_table_vpip', 'total_actions_witnessed']  0.248386  0.680145
# 6                                                  []  0.248397  0.680630
# 9                                                  []  0.252370  0.622660
# 10  ['vpip_relavant_players', 'total_actions_witne...  0.252915  0.620769
# 11  ['average_table_vpip', 'total_actions_witnessed']  0.254954  0.613454

# %%
results_6.sort_values('roc_auc', ascending=False)
# Out:
#     Unnamed: 0          model                        columns     brier  \
# 4            4  GradientBoost                             []  0.213793
# 7            7  GradientBoost  ['amount_to_call', 'callers']  0.213935
# 5            5  GradientBoost             ['amount_to_call']  0.214038
# 6            6  GradientBoost                    ['callers']  0.214152
# 8            8       AdaBoost                             []  0.248339
# 11          11       AdaBoost  ['amount_to_call', 'callers']  0.248306
# 9            9       AdaBoost             ['amount_to_call']  0.248293
# 10          10       AdaBoost                    ['callers']  0.248342
# 16          16       logistic                             []  0.218547
# 18          18       logistic                    ['callers']  0.218596
# 17          17       logistic             ['amount_to_call']  0.218634
# 19          19       logistic  ['amount_to_call', 'callers']  0.218689
# 3            3   RandomForest  ['amount_to_call', 'callers']  0.222134
# 0            0   RandomForest                             []  0.221733
# 2            2   RandomForest                    ['callers']  0.222626
# 1            1   RandomForest             ['amount_to_call']  0.222460
# 13          13            KNN             ['amount_to_call']  0.251927
# 15          15            KNN  ['amount_to_call', 'callers']  0.252574
# 14          14            KNN                    ['callers']  0.253275
# 12          12            KNN                             []  0.252915
#
#      roc_auc
# 4   0.690365
# 7   0.689597
# 5   0.689351
# 6   0.689117
# 8   0.684883
# 11  0.683554
# 9   0.683481
# 10  0.683205
# 16  0.673905
# 18  0.673703
# 17  0.673650
# 19  0.673386
# 3   0.666108
# 0   0.664685
# 2   0.664335
# 1   0.662611
# 13  0.622362
# 15  0.621787
# 14  0.621287
# 12  0.620769

# %%
results_6.sort_values('brier')
# Out:
#     Unnamed: 0          model                        columns     brier  \
# 4            4  GradientBoost                             []  0.213793
# 7            7  GradientBoost  ['amount_to_call', 'callers']  0.213935
# 5            5  GradientBoost             ['amount_to_call']  0.214038
# 6            6  GradientBoost                    ['callers']  0.214152
# 16          16       logistic                             []  0.218547
# 18          18       logistic                    ['callers']  0.218596
# 17          17       logistic             ['amount_to_call']  0.218634
# 19          19       logistic  ['amount_to_call', 'callers']  0.218689
# 0            0   RandomForest                             []  0.221733
# 3            3   RandomForest  ['amount_to_call', 'callers']  0.222134
# 1            1   RandomForest             ['amount_to_call']  0.222460
# 2            2   RandomForest                    ['callers']  0.222626
# 9            9       AdaBoost             ['amount_to_call']  0.248293
# 11          11       AdaBoost  ['amount_to_call', 'callers']  0.248306
# 8            8       AdaBoost                             []  0.248339
# 10          10       AdaBoost                    ['callers']  0.248342
# 13          13            KNN             ['amount_to_call']  0.251927
# 15          15            KNN  ['amount_to_call', 'callers']  0.252574
# 12          12            KNN                             []  0.252915
# 14          14            KNN                    ['callers']  0.253275
#
#      roc_auc
# 4   0.690365
# 7   0.689597
# 5   0.689351
# 6   0.689117
# 16  0.673905
# 18  0.673703
# 17  0.673650
# 19  0.673386
# 0   0.664685
# 3   0.666108
# 1   0.662611
# 2   0.664335
# 9   0.683481
# 11  0.683554
# 8   0.684883
# 10  0.683205
# 13  0.622362
# 15  0.621787
# 12  0.620769
# 14  0.621287

# %%
results_7.sort_values('roc_auc', ascending=False)
# Out:
#    Unnamed: 0          model     brier   roc_auc
# 1           1  GradientBoost  0.339538  0.615516
# 2           2       AdaBoost  0.341849  0.613700
# 0           0            XGB  0.359489  0.608727

# %%
results_7.sort_values('brier')
# Out:
#    Unnamed: 0          model     brier   roc_auc
# 1           1  GradientBoost  0.339538  0.615516
# 2           2       AdaBoost  0.341849  0.613700
# 0           0            XGB  0.359489  0.608727

# %%
results_8.sort_values('roc_auc', ascending=False)
# Out:
#     Unnamed: 0          model  \
# 31          31  GradientBoost
# 29          29  GradientBoost
# 23          23  GradientBoost
# 26          26  GradientBoost
# 30          30  GradientBoost
# 28          28  GradientBoost
# 20          20  GradientBoost
# 25          25  GradientBoost
# 27          27  GradientBoost
# 47          47       AdaBoost
# 24          24  GradientBoost
# 18          18  GradientBoost
# 44          44       AdaBoost
# 21          21  GradientBoost
# 46          46       AdaBoost
# 45          45       AdaBoost
# 39          39       AdaBoost
# 41          41       AdaBoost
# 40          40       AdaBoost
# 37          37       AdaBoost
# 42          42       AdaBoost
# 43          43       AdaBoost
# 36          36       AdaBoost
# 34          34       AdaBoost
# 77          77       logistic
# 79          79       logistic
# 71          71       logistic
# 76          76       logistic
# 73          73       logistic
# 78          78       logistic
# 74          74       logistic
# 68          68       logistic
# 22          22  GradientBoost
# 19          19  GradientBoost
# 17          17  GradientBoost
# 38          38       AdaBoost
# 15          15   RandomForest
# 12          12   RandomForest
# 13          13   RandomForest
# 16          16  GradientBoost
# 14          14   RandomForest
# 75          75       logistic
# 69          69       logistic
# 7            7   RandomForest
# 33          33       AdaBoost
# 66          66       logistic
# 72          72       logistic
# 35          35       AdaBoost
# 10          10   RandomForest
# 11          11   RandomForest
# 32          32       AdaBoost
# 9            9   RandomForest
# 8            8   RandomForest
# 5            5   RandomForest
# 70          70       logistic
# 2            2   RandomForest
# 4            4   RandomForest
# 65          65       logistic
# 67          67       logistic
# 64          64       logistic
# 6            6   RandomForest
# 1            1   RandomForest
# 3            3   RandomForest
# 0            0   RandomForest
# 60          60            KNN
# 63          63            KNN
# 61          61            KNN
# 55          55            KNN
# 57          57            KNN
# 53          53            KNN
# 62          62            KNN
# 52          52            KNN
# 59          59            KNN
# 58          58            KNN
# 50          50            KNN
# 56          56            KNN
# 49          49            KNN
# 54          54            KNN
# 48          48            KNN
# 51          51            KNN
#
#                                              columns     brier   roc_auc
# 31  ['suited', 'low_card', 'high_card', 'card_rank']  0.213795  0.690467
# 29              ['suited', 'high_card', 'card_rank']  0.214005  0.690033
# 23                           ['suited', 'card_rank']  0.214063  0.689672
# 26                        ['high_card', 'card_rank']  0.213974  0.689606
# 30            ['low_card', 'high_card', 'card_rank']  0.214052  0.688838
# 28               ['suited', 'low_card', 'card_rank']  0.214283  0.688704
# 20                                     ['card_rank']  0.214241  0.688523
# 25                         ['low_card', 'card_rank']  0.214618  0.686910
# 27               ['suited', 'low_card', 'high_card']  0.215331  0.685473
# 47  ['suited', 'low_card', 'high_card', 'card_rank']  0.248339  0.684883
# 24                         ['low_card', 'high_card']  0.215725  0.684006
# 18                                      ['low_card']  0.215924  0.683255
# 44               ['suited', 'low_card', 'card_rank']  0.248350  0.683177
# 21                            ['suited', 'low_card']  0.215984  0.683158
# 46            ['low_card', 'high_card', 'card_rank']  0.248359  0.682461
# 45              ['suited', 'high_card', 'card_rank']  0.248359  0.682002
# 39                           ['suited', 'card_rank']  0.248414  0.681332
# 41                         ['low_card', 'card_rank']  0.248364  0.681325
# 40                         ['low_card', 'high_card']  0.248425  0.680101
# 37                            ['suited', 'low_card']  0.248371  0.680077
# 42                        ['high_card', 'card_rank']  0.248382  0.679901
# 43               ['suited', 'low_card', 'high_card']  0.248380  0.679630
# 36                                     ['card_rank']  0.248379  0.678305
# 34                                      ['low_card']  0.248444  0.678127
# 77              ['suited', 'high_card', 'card_rank']  0.218521  0.674081
# 79  ['suited', 'low_card', 'high_card', 'card_rank']  0.218547  0.673905
# 71                           ['suited', 'card_rank']  0.218541  0.673757
# 76               ['suited', 'low_card', 'card_rank']  0.218615  0.673477
# 73                         ['low_card', 'card_rank']  0.219805  0.669162
# 78            ['low_card', 'high_card', 'card_rank']  0.219834  0.669089
# 74                        ['high_card', 'card_rank']  0.219879  0.669077
# 68                                     ['card_rank']  0.219859  0.668891
# 22                           ['suited', 'high_card']  0.219526  0.668401
# 19                                     ['high_card']  0.220454  0.665096
# 17                                        ['suited']  0.220534  0.664774
# 38                           ['suited', 'high_card']  0.248587  0.663539
# 15  ['suited', 'low_card', 'high_card', 'card_rank']  0.222131  0.663142
# 12               ['suited', 'low_card', 'card_rank']  0.223812  0.662888
# 13              ['suited', 'high_card', 'card_rank']  0.222774  0.661751
# 16                                                []  0.221239  0.661599
# 14            ['low_card', 'high_card', 'card_rank']  0.223643  0.661352
# 75               ['suited', 'low_card', 'high_card']  0.221440  0.660661
# 69                            ['suited', 'low_card']  0.221436  0.660530
# 7                            ['suited', 'card_rank']  0.224689  0.660160
# 33                                        ['suited']  0.248639  0.659630
# 66                                      ['low_card']  0.222068  0.658685
# 72                         ['low_card', 'high_card']  0.222112  0.658453
# 35                                     ['high_card']  0.248666  0.658402
# 10                        ['high_card', 'card_rank']  0.225468  0.656263
# 11               ['suited', 'low_card', 'high_card']  0.224472  0.655994
# 32                                                []  0.248694  0.655540
# 9                          ['low_card', 'card_rank']  0.225112  0.655278
# 8                          ['low_card', 'high_card']  0.225882  0.655059
# 5                             ['suited', 'low_card']  0.225243  0.653249
# 70                           ['suited', 'high_card']  0.223493  0.651562
# 2                                       ['low_card']  0.227205  0.648813
# 4                                      ['card_rank']  0.228225  0.648565
# 65                                        ['suited']  0.224322  0.647748
# 67                                     ['high_card']  0.224953  0.646728
# 64                                                []  0.225616  0.643109
# 6                            ['suited', 'high_card']  0.230325  0.642861
# 1                                         ['suited']  0.233489  0.634215
# 3                                      ['high_card']  0.232768  0.633227
# 0                                                 []  0.238218  0.623655
# 60               ['suited', 'low_card', 'card_rank']  0.252214  0.621648
# 63  ['suited', 'low_card', 'high_card', 'card_rank']  0.252915  0.620769
# 61              ['suited', 'high_card', 'card_rank']  0.252900  0.620676
# 55                           ['suited', 'card_rank']  0.254662  0.616798
# 57                         ['low_card', 'card_rank']  0.254287  0.616637
# 53                            ['suited', 'low_card']  0.255095  0.615091
# 62            ['low_card', 'high_card', 'card_rank']  0.255450  0.615089
# 52                                     ['card_rank']  0.255187  0.615067
# 59               ['suited', 'low_card', 'high_card']  0.255285  0.612676
# 58                        ['high_card', 'card_rank']  0.257075  0.611028
# 50                                      ['low_card']  0.257898  0.606987
# 56                         ['low_card', 'high_card']  0.258740  0.604133
# 49                                        ['suited']  0.259766  0.601697
# 54                           ['suited', 'high_card']  0.262029  0.595642
# 48                                                []  0.261762  0.594170
# 51                                     ['high_card']  0.262589  0.593021

# %%
results_8.sort_values('brier')
# Out:
#     Unnamed: 0          model  \
# 31          31  GradientBoost
# 26          26  GradientBoost
# 29          29  GradientBoost
# 30          30  GradientBoost
# 23          23  GradientBoost
# 20          20  GradientBoost
# 28          28  GradientBoost
# 25          25  GradientBoost
# 27          27  GradientBoost
# 24          24  GradientBoost
# 18          18  GradientBoost
# 21          21  GradientBoost
# 77          77       logistic
# 71          71       logistic
# 79          79       logistic
# 76          76       logistic
# 22          22  GradientBoost
# 73          73       logistic
# 78          78       logistic
# 68          68       logistic
# 74          74       logistic
# 19          19  GradientBoost
# 17          17  GradientBoost
# 16          16  GradientBoost
# 69          69       logistic
# 75          75       logistic
# 66          66       logistic
# 72          72       logistic
# 15          15   RandomForest
# 13          13   RandomForest
# 70          70       logistic
# 14          14   RandomForest
# 12          12   RandomForest
# 65          65       logistic
# 11          11   RandomForest
# 7            7   RandomForest
# 67          67       logistic
# 9            9   RandomForest
# 5            5   RandomForest
# 10          10   RandomForest
# 64          64       logistic
# 8            8   RandomForest
# 2            2   RandomForest
# 4            4   RandomForest
# 6            6   RandomForest
# 3            3   RandomForest
# 1            1   RandomForest
# 0            0   RandomForest
# 47          47       AdaBoost
# 44          44       AdaBoost
# 45          45       AdaBoost
# 46          46       AdaBoost
# 41          41       AdaBoost
# 37          37       AdaBoost
# 36          36       AdaBoost
# 43          43       AdaBoost
# 42          42       AdaBoost
# 39          39       AdaBoost
# 40          40       AdaBoost
# 34          34       AdaBoost
# 38          38       AdaBoost
# 33          33       AdaBoost
# 35          35       AdaBoost
# 32          32       AdaBoost
# 60          60            KNN
# 61          61            KNN
# 63          63            KNN
# 57          57            KNN
# 55          55            KNN
# 53          53            KNN
# 52          52            KNN
# 59          59            KNN
# 62          62            KNN
# 58          58            KNN
# 50          50            KNN
# 56          56            KNN
# 49          49            KNN
# 48          48            KNN
# 54          54            KNN
# 51          51            KNN
#
#                                              columns     brier   roc_auc
# 31  ['suited', 'low_card', 'high_card', 'card_rank']  0.213795  0.690467
# 26                        ['high_card', 'card_rank']  0.213974  0.689606
# 29              ['suited', 'high_card', 'card_rank']  0.214005  0.690033
# 30            ['low_card', 'high_card', 'card_rank']  0.214052  0.688838
# 23                           ['suited', 'card_rank']  0.214063  0.689672
# 20                                     ['card_rank']  0.214241  0.688523
# 28               ['suited', 'low_card', 'card_rank']  0.214283  0.688704
# 25                         ['low_card', 'card_rank']  0.214618  0.686910
# 27               ['suited', 'low_card', 'high_card']  0.215331  0.685473
# 24                         ['low_card', 'high_card']  0.215725  0.684006
# 18                                      ['low_card']  0.215924  0.683255
# 21                            ['suited', 'low_card']  0.215984  0.683158
# 77              ['suited', 'high_card', 'card_rank']  0.218521  0.674081
# 71                           ['suited', 'card_rank']  0.218541  0.673757
# 79  ['suited', 'low_card', 'high_card', 'card_rank']  0.218547  0.673905
# 76               ['suited', 'low_card', 'card_rank']  0.218615  0.673477
# 22                           ['suited', 'high_card']  0.219526  0.668401
# 73                         ['low_card', 'card_rank']  0.219805  0.669162
# 78            ['low_card', 'high_card', 'card_rank']  0.219834  0.669089
# 68                                     ['card_rank']  0.219859  0.668891
# 74                        ['high_card', 'card_rank']  0.219879  0.669077
# 19                                     ['high_card']  0.220454  0.665096
# 17                                        ['suited']  0.220534  0.664774
# 16                                                []  0.221239  0.661599
# 69                            ['suited', 'low_card']  0.221436  0.660530
# 75               ['suited', 'low_card', 'high_card']  0.221440  0.660661
# 66                                      ['low_card']  0.222068  0.658685
# 72                         ['low_card', 'high_card']  0.222112  0.658453
# 15  ['suited', 'low_card', 'high_card', 'card_rank']  0.222131  0.663142
# 13              ['suited', 'high_card', 'card_rank']  0.222774  0.661751
# 70                           ['suited', 'high_card']  0.223493  0.651562
# 14            ['low_card', 'high_card', 'card_rank']  0.223643  0.661352
# 12               ['suited', 'low_card', 'card_rank']  0.223812  0.662888
# 65                                        ['suited']  0.224322  0.647748
# 11               ['suited', 'low_card', 'high_card']  0.224472  0.655994
# 7                            ['suited', 'card_rank']  0.224689  0.660160
# 67                                     ['high_card']  0.224953  0.646728
# 9                          ['low_card', 'card_rank']  0.225112  0.655278
# 5                             ['suited', 'low_card']  0.225243  0.653249
# 10                        ['high_card', 'card_rank']  0.225468  0.656263
# 64                                                []  0.225616  0.643109
# 8                          ['low_card', 'high_card']  0.225882  0.655059
# 2                                       ['low_card']  0.227205  0.648813
# 4                                      ['card_rank']  0.228225  0.648565
# 6                            ['suited', 'high_card']  0.230325  0.642861
# 3                                      ['high_card']  0.232768  0.633227
# 1                                         ['suited']  0.233489  0.634215
# 0                                                 []  0.238218  0.623655
# 47  ['suited', 'low_card', 'high_card', 'card_rank']  0.248339  0.684883
# 44               ['suited', 'low_card', 'card_rank']  0.248350  0.683177
# 45              ['suited', 'high_card', 'card_rank']  0.248359  0.682002
# 46            ['low_card', 'high_card', 'card_rank']  0.248359  0.682461
# 41                         ['low_card', 'card_rank']  0.248364  0.681325
# 37                            ['suited', 'low_card']  0.248371  0.680077
# 36                                     ['card_rank']  0.248379  0.678305
# 43               ['suited', 'low_card', 'high_card']  0.248380  0.679630
# 42                        ['high_card', 'card_rank']  0.248382  0.679901
# 39                           ['suited', 'card_rank']  0.248414  0.681332
# 40                         ['low_card', 'high_card']  0.248425  0.680101
# 34                                      ['low_card']  0.248444  0.678127
# 38                           ['suited', 'high_card']  0.248587  0.663539
# 33                                        ['suited']  0.248639  0.659630
# 35                                     ['high_card']  0.248666  0.658402
# 32                                                []  0.248694  0.655540
# 60               ['suited', 'low_card', 'card_rank']  0.252214  0.621648
# 61              ['suited', 'high_card', 'card_rank']  0.252900  0.620676
# 63  ['suited', 'low_card', 'high_card', 'card_rank']  0.252915  0.620769
# 57                         ['low_card', 'card_rank']  0.254287  0.616637
# 55                           ['suited', 'card_rank']  0.254662  0.616798
# 53                            ['suited', 'low_card']  0.255095  0.615091
# 52                                     ['card_rank']  0.255187  0.615067
# 59               ['suited', 'low_card', 'high_card']  0.255285  0.612676
# 62            ['low_card', 'high_card', 'card_rank']  0.255450  0.615089
# 58                        ['high_card', 'card_rank']  0.257075  0.611028
# 50                                      ['low_card']  0.257898  0.606987
# 56                         ['low_card', 'high_card']  0.258740  0.604133
# 49                                        ['suited']  0.259766  0.601697
# 48                                                []  0.261762  0.594170
# 54                           ['suited', 'high_card']  0.262029  0.595642
# 51                                     ['high_card']  0.262589  0.593021

# %%
results_9.sort_values('roc_auc', ascending=False)
# Out:
#     Unnamed: 0          model  \
# 20          20  GradientBoost
# 28          28  GradientBoost
# 29          29  GradientBoost
# 30          30  GradientBoost
# 23          23  GradientBoost
# 31          31  GradientBoost
# 25          25  GradientBoost
# 26          26  GradientBoost
# 18          18  GradientBoost
# 47          47       AdaBoost
# 46          46       AdaBoost
# 24          24  GradientBoost
# 27          27  GradientBoost
# 44          44       AdaBoost
# 45          45       AdaBoost
# 17          17  GradientBoost
# 36          36       AdaBoost
# 42          42       AdaBoost
# 21          21  GradientBoost
# 16          16  GradientBoost
# 19          19  GradientBoost
# 41          41       AdaBoost
# 39          39       AdaBoost
# 22          22  GradientBoost
# 34          34       AdaBoost
# 33          33       AdaBoost
# 40          40       AdaBoost
# 37          37       AdaBoost
# 38          38       AdaBoost
# 32          32       AdaBoost
# 35          35       AdaBoost
# 43          43       AdaBoost
# 76          76       logistic
# 71          71       logistic
# 68          68       logistic
# 73          73       logistic
# 77          77       logistic
# 79          79       logistic
# 74          74       logistic
# 78          78       logistic
# 69          69       logistic
# 65          65       logistic
# 75          75       logistic
# 70          70       logistic
# 64          64       logistic
# 66          66       logistic
# 72          72       logistic
# 67          67       logistic
# 7            7   RandomForest
# 9            9   RandomForest
# 12          12   RandomForest
# 14          14   RandomForest
# 13          13   RandomForest
# 15          15   RandomForest
# 10          10   RandomForest
# 4            4   RandomForest
# 8            8   RandomForest
# 1            1   RandomForest
# 2            2   RandomForest
# 6            6   RandomForest
# 5            5   RandomForest
# 0            0   RandomForest
# 3            3   RandomForest
# 11          11   RandomForest
# 53          53            KNN
# 50          50            KNN
# 60          60            KNN
# 57          57            KNN
# 59          59            KNN
# 49          49            KNN
# 62          62            KNN
# 63          63            KNN
# 56          56            KNN
# 52          52            KNN
# 55          55            KNN
# 48          48            KNN
# 58          58            KNN
# 61          61            KNN
# 54          54            KNN
# 51          51            KNN
#
#                                               columns     brier   roc_auc
# 20                                    ['BB_in_stack']  0.213577  0.691494
# 28       ['total_players', 'position', 'BB_in_stack']  0.213609  0.691271
# 29          ['total_players', 'buyin', 'BB_in_stack']  0.213930  0.690787
# 30               ['position', 'buyin', 'BB_in_stack']  0.213569  0.690746
# 23                   ['total_players', 'BB_in_stack']  0.213840  0.690501
# 31  ['total_players', 'position', 'buyin', 'BB_in_...  0.213771  0.690391
# 25                        ['position', 'BB_in_stack']  0.213825  0.690204
# 26                           ['buyin', 'BB_in_stack']  0.213948  0.689912
# 18                                       ['position']  0.215086  0.684884
# 47  ['total_players', 'position', 'buyin', 'BB_in_...  0.248339  0.684883
# 46               ['position', 'buyin', 'BB_in_stack']  0.248352  0.684052
# 24                              ['position', 'buyin']  0.215207  0.683617
# 27             ['total_players', 'position', 'buyin']  0.215539  0.683050
# 44       ['total_players', 'position', 'BB_in_stack']  0.248359  0.683024
# 45          ['total_players', 'buyin', 'BB_in_stack']  0.248368  0.683006
# 17                                  ['total_players']  0.215845  0.682934
# 36                                    ['BB_in_stack']  0.248343  0.682722
# 42                           ['buyin', 'BB_in_stack']  0.248376  0.682671
# 21                      ['total_players', 'position']  0.215588  0.682596
# 16                                                 []  0.215634  0.682398
# 19                                          ['buyin']  0.215575  0.682113
# 41                        ['position', 'BB_in_stack']  0.248401  0.682059
# 39                   ['total_players', 'BB_in_stack']  0.248369  0.681847
# 22                         ['total_players', 'buyin']  0.216619  0.679279
# 34                                       ['position']  0.248496  0.678324
# 33                                  ['total_players']  0.248481  0.677390
# 40                              ['position', 'buyin']  0.248501  0.676619
# 37                      ['total_players', 'position']  0.248496  0.676419
# 38                         ['total_players', 'buyin']  0.248486  0.676123
# 32                                                 []  0.248511  0.676117
# 35                                          ['buyin']  0.248498  0.675738
# 43             ['total_players', 'position', 'buyin']  0.248467  0.674898
# 76       ['total_players', 'position', 'BB_in_stack']  0.218328  0.674807
# 71                   ['total_players', 'BB_in_stack']  0.218299  0.674635
# 68                                    ['BB_in_stack']  0.218364  0.674553
# 73                        ['position', 'BB_in_stack']  0.218391  0.674510
# 77          ['total_players', 'buyin', 'BB_in_stack']  0.218518  0.673958
# 79  ['total_players', 'position', 'buyin', 'BB_in_...  0.218547  0.673905
# 74                           ['buyin', 'BB_in_stack']  0.218615  0.673590
# 78               ['position', 'buyin', 'BB_in_stack']  0.218637  0.673584
# 69                      ['total_players', 'position']  0.218522  0.673547
# 65                                  ['total_players']  0.218506  0.673359
# 75             ['total_players', 'position', 'buyin']  0.218744  0.672745
# 70                         ['total_players', 'buyin']  0.218729  0.672518
# 64                                                 []  0.218746  0.672360
# 66                                       ['position']  0.218775  0.672276
# 72                              ['position', 'buyin']  0.218969  0.671434
# 67                                          ['buyin']  0.218947  0.671429
# 7                    ['total_players', 'BB_in_stack']  0.222935  0.664380
# 9                         ['position', 'BB_in_stack']  0.223121  0.663941
# 12       ['total_players', 'position', 'BB_in_stack']  0.222831  0.663410
# 14               ['position', 'buyin', 'BB_in_stack']  0.223158  0.662686
# 13          ['total_players', 'buyin', 'BB_in_stack']  0.222747  0.661774
# 15  ['total_players', 'position', 'buyin', 'BB_in_...  0.222846  0.661374
# 10                           ['buyin', 'BB_in_stack']  0.223110  0.660469
# 4                                     ['BB_in_stack']  0.224529  0.660045
# 8                               ['position', 'buyin']  0.228382  0.653120
# 1                                   ['total_players']  0.229981  0.652357
# 2                                        ['position']  0.230164  0.651239
# 6                          ['total_players', 'buyin']  0.228143  0.649378
# 5                       ['total_players', 'position']  0.229823  0.648022
# 0                                                  []  0.233834  0.647353
# 3                                           ['buyin']  0.229773  0.646617
# 11             ['total_players', 'position', 'buyin']  0.228268  0.646588
# 53                      ['total_players', 'position']  0.249251  0.630919
# 50                                       ['position']  0.250418  0.627748
# 60       ['total_players', 'position', 'BB_in_stack']  0.251835  0.626484
# 57                        ['position', 'BB_in_stack']  0.251465  0.625513
# 59             ['total_players', 'position', 'buyin']  0.252321  0.621245
# 49                                  ['total_players']  0.253752  0.620966
# 62               ['position', 'buyin', 'BB_in_stack']  0.252905  0.620840
# 63  ['total_players', 'position', 'buyin', 'BB_in_...  0.252915  0.620769
# 56                              ['position', 'buyin']  0.252832  0.618924
# 52                                    ['BB_in_stack']  0.253839  0.618760
# 55                   ['total_players', 'BB_in_stack']  0.255192  0.617629
# 48                                                 []  0.254959  0.615453
# 58                           ['buyin', 'BB_in_stack']  0.254798  0.615097
# 61          ['total_players', 'buyin', 'BB_in_stack']  0.256146  0.612654
# 54                         ['total_players', 'buyin']  0.256866  0.611709
# 51                                          ['buyin']  0.255922  0.611481

# %%
results_9.sort_values('brier')
# Out:
#     Unnamed: 0          model  \
# 30          30  GradientBoost
# 20          20  GradientBoost
# 28          28  GradientBoost
# 31          31  GradientBoost
# 25          25  GradientBoost
# 23          23  GradientBoost
# 29          29  GradientBoost
# 26          26  GradientBoost
# 18          18  GradientBoost
# 24          24  GradientBoost
# 27          27  GradientBoost
# 19          19  GradientBoost
# 21          21  GradientBoost
# 16          16  GradientBoost
# 17          17  GradientBoost
# 22          22  GradientBoost
# 71          71       logistic
# 76          76       logistic
# 68          68       logistic
# 73          73       logistic
# 65          65       logistic
# 77          77       logistic
# 69          69       logistic
# 79          79       logistic
# 74          74       logistic
# 78          78       logistic
# 70          70       logistic
# 75          75       logistic
# 64          64       logistic
# 66          66       logistic
# 67          67       logistic
# 72          72       logistic
# 13          13   RandomForest
# 12          12   RandomForest
# 15          15   RandomForest
# 7            7   RandomForest
# 10          10   RandomForest
# 9            9   RandomForest
# 14          14   RandomForest
# 4            4   RandomForest
# 6            6   RandomForest
# 11          11   RandomForest
# 8            8   RandomForest
# 3            3   RandomForest
# 5            5   RandomForest
# 1            1   RandomForest
# 2            2   RandomForest
# 0            0   RandomForest
# 47          47       AdaBoost
# 36          36       AdaBoost
# 46          46       AdaBoost
# 44          44       AdaBoost
# 45          45       AdaBoost
# 39          39       AdaBoost
# 42          42       AdaBoost
# 41          41       AdaBoost
# 43          43       AdaBoost
# 33          33       AdaBoost
# 38          38       AdaBoost
# 37          37       AdaBoost
# 34          34       AdaBoost
# 35          35       AdaBoost
# 40          40       AdaBoost
# 32          32       AdaBoost
# 53          53            KNN
# 50          50            KNN
# 57          57            KNN
# 60          60            KNN
# 59          59            KNN
# 56          56            KNN
# 62          62            KNN
# 63          63            KNN
# 49          49            KNN
# 52          52            KNN
# 58          58            KNN
# 48          48            KNN
# 55          55            KNN
# 51          51            KNN
# 61          61            KNN
# 54          54            KNN
#
#                                               columns     brier   roc_auc
# 30               ['position', 'buyin', 'BB_in_stack']  0.213569  0.690746
# 20                                    ['BB_in_stack']  0.213577  0.691494
# 28       ['total_players', 'position', 'BB_in_stack']  0.213609  0.691271
# 31  ['total_players', 'position', 'buyin', 'BB_in_...  0.213771  0.690391
# 25                        ['position', 'BB_in_stack']  0.213825  0.690204
# 23                   ['total_players', 'BB_in_stack']  0.213840  0.690501
# 29          ['total_players', 'buyin', 'BB_in_stack']  0.213930  0.690787
# 26                           ['buyin', 'BB_in_stack']  0.213948  0.689912
# 18                                       ['position']  0.215086  0.684884
# 24                              ['position', 'buyin']  0.215207  0.683617
# 27             ['total_players', 'position', 'buyin']  0.215539  0.683050
# 19                                          ['buyin']  0.215575  0.682113
# 21                      ['total_players', 'position']  0.215588  0.682596
# 16                                                 []  0.215634  0.682398
# 17                                  ['total_players']  0.215845  0.682934
# 22                         ['total_players', 'buyin']  0.216619  0.679279
# 71                   ['total_players', 'BB_in_stack']  0.218299  0.674635
# 76       ['total_players', 'position', 'BB_in_stack']  0.218328  0.674807
# 68                                    ['BB_in_stack']  0.218364  0.674553
# 73                        ['position', 'BB_in_stack']  0.218391  0.674510
# 65                                  ['total_players']  0.218506  0.673359
# 77          ['total_players', 'buyin', 'BB_in_stack']  0.218518  0.673958
# 69                      ['total_players', 'position']  0.218522  0.673547
# 79  ['total_players', 'position', 'buyin', 'BB_in_...  0.218547  0.673905
# 74                           ['buyin', 'BB_in_stack']  0.218615  0.673590
# 78               ['position', 'buyin', 'BB_in_stack']  0.218637  0.673584
# 70                         ['total_players', 'buyin']  0.218729  0.672518
# 75             ['total_players', 'position', 'buyin']  0.218744  0.672745
# 64                                                 []  0.218746  0.672360
# 66                                       ['position']  0.218775  0.672276
# 67                                          ['buyin']  0.218947  0.671429
# 72                              ['position', 'buyin']  0.218969  0.671434
# 13          ['total_players', 'buyin', 'BB_in_stack']  0.222747  0.661774
# 12       ['total_players', 'position', 'BB_in_stack']  0.222831  0.663410
# 15  ['total_players', 'position', 'buyin', 'BB_in_...  0.222846  0.661374
# 7                    ['total_players', 'BB_in_stack']  0.222935  0.664380
# 10                           ['buyin', 'BB_in_stack']  0.223110  0.660469
# 9                         ['position', 'BB_in_stack']  0.223121  0.663941
# 14               ['position', 'buyin', 'BB_in_stack']  0.223158  0.662686
# 4                                     ['BB_in_stack']  0.224529  0.660045
# 6                          ['total_players', 'buyin']  0.228143  0.649378
# 11             ['total_players', 'position', 'buyin']  0.228268  0.646588
# 8                               ['position', 'buyin']  0.228382  0.653120
# 3                                           ['buyin']  0.229773  0.646617
# 5                       ['total_players', 'position']  0.229823  0.648022
# 1                                   ['total_players']  0.229981  0.652357
# 2                                        ['position']  0.230164  0.651239
# 0                                                  []  0.233834  0.647353
# 47  ['total_players', 'position', 'buyin', 'BB_in_...  0.248339  0.684883
# 36                                    ['BB_in_stack']  0.248343  0.682722
# 46               ['position', 'buyin', 'BB_in_stack']  0.248352  0.684052
# 44       ['total_players', 'position', 'BB_in_stack']  0.248359  0.683024
# 45          ['total_players', 'buyin', 'BB_in_stack']  0.248368  0.683006
# 39                   ['total_players', 'BB_in_stack']  0.248369  0.681847
# 42                           ['buyin', 'BB_in_stack']  0.248376  0.682671
# 41                        ['position', 'BB_in_stack']  0.248401  0.682059
# 43             ['total_players', 'position', 'buyin']  0.248467  0.674898
# 33                                  ['total_players']  0.248481  0.677390
# 38                         ['total_players', 'buyin']  0.248486  0.676123
# 37                      ['total_players', 'position']  0.248496  0.676419
# 34                                       ['position']  0.248496  0.678324
# 35                                          ['buyin']  0.248498  0.675738
# 40                              ['position', 'buyin']  0.248501  0.676619
# 32                                                 []  0.248511  0.676117
# 53                      ['total_players', 'position']  0.249251  0.630919
# 50                                       ['position']  0.250418  0.627748
# 57                        ['position', 'BB_in_stack']  0.251465  0.625513
# 60       ['total_players', 'position', 'BB_in_stack']  0.251835  0.626484
# 59             ['total_players', 'position', 'buyin']  0.252321  0.621245
# 56                              ['position', 'buyin']  0.252832  0.618924
# 62               ['position', 'buyin', 'BB_in_stack']  0.252905  0.620840
# 63  ['total_players', 'position', 'buyin', 'BB_in_...  0.252915  0.620769
# 49                                  ['total_players']  0.253752  0.620966
# 52                                    ['BB_in_stack']  0.253839  0.618760
# 58                           ['buyin', 'BB_in_stack']  0.254798  0.615097
# 48                                                 []  0.254959  0.615453
# 55                   ['total_players', 'BB_in_stack']  0.255192  0.617629
# 51                                          ['buyin']  0.255922  0.611481
# 61          ['total_players', 'buyin', 'BB_in_stack']  0.256146  0.612654
# 54                         ['total_players', 'buyin']  0.256866  0.611709

# %%
results_10.sort_values('roc_auc', ascending=False)
# Out:
#     Unnamed: 0          model  \
# 11          11  GradientBoost
# 15          15  GradientBoost
# 13          13  GradientBoost
# 14          14  GradientBoost
# 9            9  GradientBoost
# 8            8  GradientBoost
# 10          10  GradientBoost
# 12          12  GradientBoost
# 23          23       AdaBoost
# 19          19       AdaBoost
# 22          22       AdaBoost
# 21          21       AdaBoost
# 16          16       AdaBoost
# 20          20       AdaBoost
# 18          18       AdaBoost
# 17          17       AdaBoost
# 35          35       logistic
# 37          37       logistic
# 38          38       logistic
# 39          39       logistic
# 32          32       logistic
# 33          33       logistic
# 34          34       logistic
# 36          36       logistic
# 7            7   RandomForest
# 5            5   RandomForest
# 6            6   RandomForest
# 2            2   RandomForest
# 4            4   RandomForest
# 1            1   RandomForest
# 3            3   RandomForest
# 0            0   RandomForest
# 25          25            KNN
# 29          29            KNN
# 28          28            KNN
# 31          31            KNN
# 24          24            KNN
# 27          27            KNN
# 26          26            KNN
# 30          30            KNN
#
#                                               columns     brier   roc_auc
# 11       ['total_actions_witnessed_relevant_players']  0.213592  0.691400
# 15  ['position', 'buyin', 'total_actions_witnessed...  0.213520  0.690669
# 13  ['position', 'total_actions_witnessed_relevant...  0.213820  0.690193
# 14  ['buyin', 'total_actions_witnessed_relevant_pl...  0.213887  0.689828
# 9                                        ['position']  0.214612  0.687107
# 8                                                  []  0.214664  0.686464
# 10                                          ['buyin']  0.214804  0.686160
# 12                              ['position', 'buyin']  0.214805  0.686048
# 23  ['position', 'buyin', 'total_actions_witnessed...  0.248352  0.684052
# 19       ['total_actions_witnessed_relevant_players']  0.248343  0.682722
# 22  ['buyin', 'total_actions_witnessed_relevant_pl...  0.248376  0.682671
# 21  ['position', 'total_actions_witnessed_relevant...  0.248401  0.682059
# 16                                                 []  0.248356  0.682057
# 20                              ['position', 'buyin']  0.248363  0.680683
# 18                                          ['buyin']  0.248364  0.680649
# 17                                       ['position']  0.248331  0.680035
# 35       ['total_actions_witnessed_relevant_players']  0.218364  0.674553
# 37  ['position', 'total_actions_witnessed_relevant...  0.218391  0.674510
# 38  ['buyin', 'total_actions_witnessed_relevant_pl...  0.218615  0.673590
# 39  ['position', 'buyin', 'total_actions_witnessed...  0.218637  0.673584
# 32                                                 []  0.218886  0.672237
# 33                                       ['position']  0.218911  0.672215
# 34                                          ['buyin']  0.219099  0.671555
# 36                              ['position', 'buyin']  0.219119  0.671481
# 7   ['position', 'buyin', 'total_actions_witnessed...  0.222678  0.663027
# 5   ['position', 'total_actions_witnessed_relevant...  0.223647  0.662671
# 6   ['buyin', 'total_actions_witnessed_relevant_pl...  0.223323  0.662633
# 2                                           ['buyin']  0.225589  0.661773
# 4                               ['position', 'buyin']  0.225709  0.661168
# 1                                        ['position']  0.225773  0.659971
# 3        ['total_actions_witnessed_relevant_players']  0.224312  0.658558
# 0                                                  []  0.227590  0.655595
# 25                                       ['position']  0.249051  0.630783
# 29  ['position', 'total_actions_witnessed_relevant...  0.251465  0.625513
# 28                              ['position', 'buyin']  0.252268  0.622354
# 31  ['position', 'buyin', 'total_actions_witnessed...  0.252905  0.620840
# 24                                                 []  0.254005  0.619573
# 27       ['total_actions_witnessed_relevant_players']  0.253839  0.618760
# 26                                          ['buyin']  0.255747  0.615163
# 30  ['buyin', 'total_actions_witnessed_relevant_pl...  0.254798  0.615097

# %%
results_10.sort_values('brier')
# Out:
#     Unnamed: 0          model  \
# 15          15  GradientBoost
# 11          11  GradientBoost
# 13          13  GradientBoost
# 14          14  GradientBoost
# 9            9  GradientBoost
# 8            8  GradientBoost
# 10          10  GradientBoost
# 12          12  GradientBoost
# 35          35       logistic
# 37          37       logistic
# 38          38       logistic
# 39          39       logistic
# 32          32       logistic
# 33          33       logistic
# 34          34       logistic
# 36          36       logistic
# 7            7   RandomForest
# 6            6   RandomForest
# 5            5   RandomForest
# 3            3   RandomForest
# 2            2   RandomForest
# 4            4   RandomForest
# 1            1   RandomForest
# 0            0   RandomForest
# 17          17       AdaBoost
# 19          19       AdaBoost
# 23          23       AdaBoost
# 16          16       AdaBoost
# 20          20       AdaBoost
# 18          18       AdaBoost
# 22          22       AdaBoost
# 21          21       AdaBoost
# 25          25            KNN
# 29          29            KNN
# 28          28            KNN
# 31          31            KNN
# 27          27            KNN
# 24          24            KNN
# 30          30            KNN
# 26          26            KNN
#
#                                               columns     brier   roc_auc
# 15  ['position', 'buyin', 'total_actions_witnessed...  0.213520  0.690669
# 11       ['total_actions_witnessed_relevant_players']  0.213592  0.691400
# 13  ['position', 'total_actions_witnessed_relevant...  0.213820  0.690193
# 14  ['buyin', 'total_actions_witnessed_relevant_pl...  0.213887  0.689828
# 9                                        ['position']  0.214612  0.687107
# 8                                                  []  0.214664  0.686464
# 10                                          ['buyin']  0.214804  0.686160
# 12                              ['position', 'buyin']  0.214805  0.686048
# 35       ['total_actions_witnessed_relevant_players']  0.218364  0.674553
# 37  ['position', 'total_actions_witnessed_relevant...  0.218391  0.674510
# 38  ['buyin', 'total_actions_witnessed_relevant_pl...  0.218615  0.673590
# 39  ['position', 'buyin', 'total_actions_witnessed...  0.218637  0.673584
# 32                                                 []  0.218886  0.672237
# 33                                       ['position']  0.218911  0.672215
# 34                                          ['buyin']  0.219099  0.671555
# 36                              ['position', 'buyin']  0.219119  0.671481
# 7   ['position', 'buyin', 'total_actions_witnessed...  0.222678  0.663027
# 6   ['buyin', 'total_actions_witnessed_relevant_pl...  0.223323  0.662633
# 5   ['position', 'total_actions_witnessed_relevant...  0.223647  0.662671
# 3        ['total_actions_witnessed_relevant_players']  0.224312  0.658558
# 2                                           ['buyin']  0.225589  0.661773
# 4                               ['position', 'buyin']  0.225709  0.661168
# 1                                        ['position']  0.225773  0.659971
# 0                                                  []  0.227590  0.655595
# 17                                       ['position']  0.248331  0.680035
# 19       ['total_actions_witnessed_relevant_players']  0.248343  0.682722
# 23  ['position', 'buyin', 'total_actions_witnessed...  0.248352  0.684052
# 16                                                 []  0.248356  0.682057
# 20                              ['position', 'buyin']  0.248363  0.680683
# 18                                          ['buyin']  0.248364  0.680649
# 22  ['buyin', 'total_actions_witnessed_relevant_pl...  0.248376  0.682671
# 21  ['position', 'total_actions_witnessed_relevant...  0.248401  0.682059
# 25                                       ['position']  0.249051  0.630783
# 29  ['position', 'total_actions_witnessed_relevant...  0.251465  0.625513
# 28                              ['position', 'buyin']  0.252268  0.622354
# 31  ['position', 'buyin', 'total_actions_witnessed...  0.252905  0.620840
# 27       ['total_actions_witnessed_relevant_players']  0.253839  0.618760
# 24                                                 []  0.254005  0.619573
# 30  ['buyin', 'total_actions_witnessed_relevant_pl...  0.254798  0.615097
# 26                                          ['buyin']  0.255747  0.615163

# %%
results_11.sort_values('roc_auc', ascending=False)
# Out:
#     Unnamed: 0          model  \
# 16          16  GradientBoost
# 29          29  GradientBoost
# 18          18  GradientBoost
# 22          22  GradientBoost
# 17          17  GradientBoost
# 24          24  GradientBoost
# 28          28  GradientBoost
# 20          20  GradientBoost
# 21          21  GradientBoost
# 23          23  GradientBoost
# 30          30  GradientBoost
# 25          25  GradientBoost
# 26          26  GradientBoost
# 31          31  GradientBoost
# 19          19  GradientBoost
# 27          27  GradientBoost
# 32          32       AdaBoost
# 41          41       AdaBoost
# 36          36       AdaBoost
# 46          46       AdaBoost
# 39          39       AdaBoost
# 47          47       AdaBoost
# 40          40       AdaBoost
# 42          42       AdaBoost
# 44          44       AdaBoost
# 37          37       AdaBoost
# 33          33       AdaBoost
# 34          34       AdaBoost
# 35          35       AdaBoost
# 38          38       AdaBoost
# 43          43       AdaBoost
# 45          45       AdaBoost
# 75          75       logistic
# 70          70       logistic
# 69          69       logistic
# 79          79       logistic
# 76          76       logistic
# 77          77       logistic
# 65          65       logistic
# 71          71       logistic
# 72          72       logistic
# 67          67       logistic
# 78          78       logistic
# 66          66       logistic
# 73          73       logistic
# 74          74       logistic
# 68          68       logistic
# 64          64       logistic
# 15          15   RandomForest
# 5            5   RandomForest
# 9            9   RandomForest
# 6            6   RandomForest
# 2            2   RandomForest
# 13          13   RandomForest
# 8            8   RandomForest
# 3            3   RandomForest
# 12          12   RandomForest
# 14          14   RandomForest
# 10          10   RandomForest
# 11          11   RandomForest
# 1            1   RandomForest
# 7            7   RandomForest
# 4            4   RandomForest
# 0            0   RandomForest
# 58          58            KNN
# 62          62            KNN
# 57          57            KNN
# 50          50            KNN
# 63          63            KNN
# 52          52            KNN
# 51          51            KNN
# 56          56            KNN
# 54          54            KNN
# 59          59            KNN
# 53          53            KNN
# 61          61            KNN
# 60          60            KNN
# 49          49            KNN
# 55          55            KNN
# 48          48            KNN
#
#                                               columns     brier   roc_auc
# 16                                                 []  0.214489  0.689066
# 29  ['total_actions_witnessed_relevant_players', '...  0.214491  0.688912
# 18                          ['vpip_relavant_players']  0.214489  0.688656
# 22  ['total_actions_witnessed_relevant_players', '...  0.214659  0.688487
# 17       ['total_actions_witnessed_relevant_players']  0.214511  0.687981
# 24  ['vpip_relavant_players', 'weighted_relevant_v...  0.214762  0.687930
# 28  ['total_actions_witnessed_relevant_players', '...  0.214754  0.687877
# 20                                          ['buyin']  0.214563  0.687840
# 21  ['total_actions_witnessed_relevant_players', '...  0.214738  0.687805
# 23  ['total_actions_witnessed_relevant_players', '...  0.214571  0.687719
# 30  ['vpip_relavant_players', 'weighted_relevant_v...  0.214829  0.687683
# 25                 ['vpip_relavant_players', 'buyin']  0.214777  0.687580
# 26                ['weighted_relevant_vpip', 'buyin']  0.214805  0.687545
# 31  ['total_actions_witnessed_relevant_players', '...  0.214929  0.687173
# 19                         ['weighted_relevant_vpip']  0.214978  0.687014
# 27  ['total_actions_witnessed_relevant_players', '...  0.214955  0.686944
# 32                                                 []  0.248489  0.683296
# 41                 ['vpip_relavant_players', 'buyin']  0.248464  0.683083
# 36                                          ['buyin']  0.248472  0.683002
# 46  ['vpip_relavant_players', 'weighted_relevant_v...  0.248472  0.682279
# 39  ['total_actions_witnessed_relevant_players', '...  0.248462  0.681952
# 47  ['total_actions_witnessed_relevant_players', '...  0.248445  0.681894
# 40  ['vpip_relavant_players', 'weighted_relevant_v...  0.248468  0.681850
# 42                ['weighted_relevant_vpip', 'buyin']  0.248491  0.681711
# 44  ['total_actions_witnessed_relevant_players', '...  0.248456  0.681659
# 37  ['total_actions_witnessed_relevant_players', '...  0.248484  0.681609
# 33       ['total_actions_witnessed_relevant_players']  0.248464  0.681542
# 34                          ['vpip_relavant_players']  0.248486  0.681529
# 35                         ['weighted_relevant_vpip']  0.248478  0.680966
# 38  ['total_actions_witnessed_relevant_players', '...  0.248460  0.680809
# 43  ['total_actions_witnessed_relevant_players', '...  0.248461  0.680761
# 45  ['total_actions_witnessed_relevant_players', '...  0.248472  0.680052
# 75  ['total_actions_witnessed_relevant_players', '...  0.218728  0.674463
# 70  ['total_actions_witnessed_relevant_players', '...  0.218719  0.674417
# 69  ['total_actions_witnessed_relevant_players', '...  0.218719  0.674397
# 79  ['total_actions_witnessed_relevant_players', '...  0.218755  0.674278
# 76  ['total_actions_witnessed_relevant_players', '...  0.218745  0.674257
# 77  ['total_actions_witnessed_relevant_players', '...  0.218747  0.674250
# 65       ['total_actions_witnessed_relevant_players']  0.218819  0.673582
# 71  ['total_actions_witnessed_relevant_players', '...  0.218852  0.673468
# 72  ['vpip_relavant_players', 'weighted_relevant_v...  0.219079  0.673320
# 67                         ['weighted_relevant_vpip']  0.219070  0.673297
# 78  ['vpip_relavant_players', 'weighted_relevant_v...  0.219110  0.673265
# 66                          ['vpip_relavant_players']  0.219073  0.673263
# 73                 ['vpip_relavant_players', 'buyin']  0.219103  0.673252
# 74                ['weighted_relevant_vpip', 'buyin']  0.219101  0.673241
# 68                                          ['buyin']  0.219292  0.672135
# 64                                                 []  0.219272  0.671991
# 15  ['total_actions_witnessed_relevant_players', '...  0.223014  0.667734
# 5   ['total_actions_witnessed_relevant_players', '...  0.223302  0.664099
# 9                  ['vpip_relavant_players', 'buyin']  0.223618  0.664059
# 6   ['total_actions_witnessed_relevant_players', '...  0.223633  0.662689
# 2                           ['vpip_relavant_players']  0.225596  0.662140
# 13  ['total_actions_witnessed_relevant_players', '...  0.222620  0.662086
# 8   ['vpip_relavant_players', 'weighted_relevant_v...  0.224754  0.661951
# 3                          ['weighted_relevant_vpip']  0.226077  0.661307
# 12  ['total_actions_witnessed_relevant_players', '...  0.222463  0.661281
# 14  ['vpip_relavant_players', 'weighted_relevant_v...  0.223322  0.661183
# 10                ['weighted_relevant_vpip', 'buyin']  0.224620  0.660030
# 11  ['total_actions_witnessed_relevant_players', '...  0.222702  0.659446
# 1        ['total_actions_witnessed_relevant_players']  0.227857  0.651939
# 7   ['total_actions_witnessed_relevant_players', '...  0.228084  0.651404
# 4                                           ['buyin']  0.234025  0.644984
# 0                                                  []  0.239367  0.640033
# 58                ['weighted_relevant_vpip', 'buyin']  0.248112  0.633092
# 62  ['vpip_relavant_players', 'weighted_relevant_v...  0.248195  0.632813
# 57                 ['vpip_relavant_players', 'buyin']  0.248326  0.632725
# 50                          ['vpip_relavant_players']  0.250818  0.630318
# 63  ['total_actions_witnessed_relevant_players', '...  0.249124  0.630189
# 52                                          ['buyin']  0.250234  0.629205
# 51                         ['weighted_relevant_vpip']  0.251002  0.629058
# 56  ['vpip_relavant_players', 'weighted_relevant_v...  0.251577  0.627846
# 54  ['total_actions_witnessed_relevant_players', '...  0.251129  0.626769
# 59  ['total_actions_witnessed_relevant_players', '...  0.252185  0.626762
# 53  ['total_actions_witnessed_relevant_players', '...  0.250973  0.626730
# 61  ['total_actions_witnessed_relevant_players', '...  0.250263  0.625678
# 60  ['total_actions_witnessed_relevant_players', '...  0.250243  0.625512
# 49       ['total_actions_witnessed_relevant_players']  0.253723  0.621924
# 55  ['total_actions_witnessed_relevant_players', '...  0.252672  0.621072
# 48                                                 []  0.257139  0.618276

# %%
results_11.sort_values('brier')
# Out:
#     Unnamed: 0          model  \
# 18          18  GradientBoost
# 16          16  GradientBoost
# 29          29  GradientBoost
# 17          17  GradientBoost
# 20          20  GradientBoost
# 23          23  GradientBoost
# 22          22  GradientBoost
# 21          21  GradientBoost
# 28          28  GradientBoost
# 24          24  GradientBoost
# 25          25  GradientBoost
# 26          26  GradientBoost
# 30          30  GradientBoost
# 31          31  GradientBoost
# 27          27  GradientBoost
# 19          19  GradientBoost
# 69          69       logistic
# 70          70       logistic
# 75          75       logistic
# 76          76       logistic
# 77          77       logistic
# 79          79       logistic
# 65          65       logistic
# 71          71       logistic
# 67          67       logistic
# 66          66       logistic
# 72          72       logistic
# 74          74       logistic
# 73          73       logistic
# 78          78       logistic
# 64          64       logistic
# 68          68       logistic
# 12          12   RandomForest
# 13          13   RandomForest
# 11          11   RandomForest
# 15          15   RandomForest
# 5            5   RandomForest
# 14          14   RandomForest
# 9            9   RandomForest
# 6            6   RandomForest
# 10          10   RandomForest
# 8            8   RandomForest
# 2            2   RandomForest
# 3            3   RandomForest
# 1            1   RandomForest
# 7            7   RandomForest
# 4            4   RandomForest
# 0            0   RandomForest
# 58          58            KNN
# 62          62            KNN
# 57          57            KNN
# 47          47       AdaBoost
# 44          44       AdaBoost
# 38          38       AdaBoost
# 43          43       AdaBoost
# 39          39       AdaBoost
# 41          41       AdaBoost
# 33          33       AdaBoost
# 40          40       AdaBoost
# 45          45       AdaBoost
# 46          46       AdaBoost
# 36          36       AdaBoost
# 35          35       AdaBoost
# 37          37       AdaBoost
# 34          34       AdaBoost
# 32          32       AdaBoost
# 42          42       AdaBoost
# 63          63            KNN
# 52          52            KNN
# 60          60            KNN
# 61          61            KNN
# 50          50            KNN
# 53          53            KNN
# 51          51            KNN
# 54          54            KNN
# 56          56            KNN
# 59          59            KNN
# 55          55            KNN
# 49          49            KNN
# 48          48            KNN
#
#                                               columns     brier   roc_auc
# 18                          ['vpip_relavant_players']  0.214489  0.688656
# 16                                                 []  0.214489  0.689066
# 29  ['total_actions_witnessed_relevant_players', '...  0.214491  0.688912
# 17       ['total_actions_witnessed_relevant_players']  0.214511  0.687981
# 20                                          ['buyin']  0.214563  0.687840
# 23  ['total_actions_witnessed_relevant_players', '...  0.214571  0.687719
# 22  ['total_actions_witnessed_relevant_players', '...  0.214659  0.688487
# 21  ['total_actions_witnessed_relevant_players', '...  0.214738  0.687805
# 28  ['total_actions_witnessed_relevant_players', '...  0.214754  0.687877
# 24  ['vpip_relavant_players', 'weighted_relevant_v...  0.214762  0.687930
# 25                 ['vpip_relavant_players', 'buyin']  0.214777  0.687580
# 26                ['weighted_relevant_vpip', 'buyin']  0.214805  0.687545
# 30  ['vpip_relavant_players', 'weighted_relevant_v...  0.214829  0.687683
# 31  ['total_actions_witnessed_relevant_players', '...  0.214929  0.687173
# 27  ['total_actions_witnessed_relevant_players', '...  0.214955  0.686944
# 19                         ['weighted_relevant_vpip']  0.214978  0.687014
# 69  ['total_actions_witnessed_relevant_players', '...  0.218719  0.674397
# 70  ['total_actions_witnessed_relevant_players', '...  0.218719  0.674417
# 75  ['total_actions_witnessed_relevant_players', '...  0.218728  0.674463
# 76  ['total_actions_witnessed_relevant_players', '...  0.218745  0.674257
# 77  ['total_actions_witnessed_relevant_players', '...  0.218747  0.674250
# 79  ['total_actions_witnessed_relevant_players', '...  0.218755  0.674278
# 65       ['total_actions_witnessed_relevant_players']  0.218819  0.673582
# 71  ['total_actions_witnessed_relevant_players', '...  0.218852  0.673468
# 67                         ['weighted_relevant_vpip']  0.219070  0.673297
# 66                          ['vpip_relavant_players']  0.219073  0.673263
# 72  ['vpip_relavant_players', 'weighted_relevant_v...  0.219079  0.673320
# 74                ['weighted_relevant_vpip', 'buyin']  0.219101  0.673241
# 73                 ['vpip_relavant_players', 'buyin']  0.219103  0.673252
# 78  ['vpip_relavant_players', 'weighted_relevant_v...  0.219110  0.673265
# 64                                                 []  0.219272  0.671991
# 68                                          ['buyin']  0.219292  0.672135
# 12  ['total_actions_witnessed_relevant_players', '...  0.222463  0.661281
# 13  ['total_actions_witnessed_relevant_players', '...  0.222620  0.662086
# 11  ['total_actions_witnessed_relevant_players', '...  0.222702  0.659446
# 15  ['total_actions_witnessed_relevant_players', '...  0.223014  0.667734
# 5   ['total_actions_witnessed_relevant_players', '...  0.223302  0.664099
# 14  ['vpip_relavant_players', 'weighted_relevant_v...  0.223322  0.661183
# 9                  ['vpip_relavant_players', 'buyin']  0.223618  0.664059
# 6   ['total_actions_witnessed_relevant_players', '...  0.223633  0.662689
# 10                ['weighted_relevant_vpip', 'buyin']  0.224620  0.660030
# 8   ['vpip_relavant_players', 'weighted_relevant_v...  0.224754  0.661951
# 2                           ['vpip_relavant_players']  0.225596  0.662140
# 3                          ['weighted_relevant_vpip']  0.226077  0.661307
# 1        ['total_actions_witnessed_relevant_players']  0.227857  0.651939
# 7   ['total_actions_witnessed_relevant_players', '...  0.228084  0.651404
# 4                                           ['buyin']  0.234025  0.644984
# 0                                                  []  0.239367  0.640033
# 58                ['weighted_relevant_vpip', 'buyin']  0.248112  0.633092
# 62  ['vpip_relavant_players', 'weighted_relevant_v...  0.248195  0.632813
# 57                 ['vpip_relavant_players', 'buyin']  0.248326  0.632725
# 47  ['total_actions_witnessed_relevant_players', '...  0.248445  0.681894
# 44  ['total_actions_witnessed_relevant_players', '...  0.248456  0.681659
# 38  ['total_actions_witnessed_relevant_players', '...  0.248460  0.680809
# 43  ['total_actions_witnessed_relevant_players', '...  0.248461  0.680761
# 39  ['total_actions_witnessed_relevant_players', '...  0.248462  0.681952
# 41                 ['vpip_relavant_players', 'buyin']  0.248464  0.683083
# 33       ['total_actions_witnessed_relevant_players']  0.248464  0.681542
# 40  ['vpip_relavant_players', 'weighted_relevant_v...  0.248468  0.681850
# 45  ['total_actions_witnessed_relevant_players', '...  0.248472  0.680052
# 46  ['vpip_relavant_players', 'weighted_relevant_v...  0.248472  0.682279
# 36                                          ['buyin']  0.248472  0.683002
# 35                         ['weighted_relevant_vpip']  0.248478  0.680966
# 37  ['total_actions_witnessed_relevant_players', '...  0.248484  0.681609
# 34                          ['vpip_relavant_players']  0.248486  0.681529
# 32                                                 []  0.248489  0.683296
# 42                ['weighted_relevant_vpip', 'buyin']  0.248491  0.681711
# 63  ['total_actions_witnessed_relevant_players', '...  0.249124  0.630189
# 52                                          ['buyin']  0.250234  0.629205
# 60  ['total_actions_witnessed_relevant_players', '...  0.250243  0.625512
# 61  ['total_actions_witnessed_relevant_players', '...  0.250263  0.625678
# 50                          ['vpip_relavant_players']  0.250818  0.630318
# 53  ['total_actions_witnessed_relevant_players', '...  0.250973  0.626730
# 51                         ['weighted_relevant_vpip']  0.251002  0.629058
# 54  ['total_actions_witnessed_relevant_players', '...  0.251129  0.626769
# 56  ['vpip_relavant_players', 'weighted_relevant_v...  0.251577  0.627846
# 59  ['total_actions_witnessed_relevant_players', '...  0.252185  0.626762
# 55  ['total_actions_witnessed_relevant_players', '...  0.252672  0.621072
# 49       ['total_actions_witnessed_relevant_players']  0.253723  0.621924
# 48                                                 []  0.257139  0.618276

# %%
results_11['columns'].iloc[21]
# Out:
# "['position', 'total_actions_witnessed_relevant_players']"
