# %%
import pandas as pd 
pd.set_option('display.max_rows', 500)

# %%
results = pd.read_csv('../data/compare_models_features/classification_model_comparison_limps_calls_reraises.csv')
results_2 = pd.read_csv('../data/compare_models_features/classification_model_comparison_num_players_.csv')
results_3 = pd.read_csv('../data/compare_models_features/classification_model_table_stats.csv')
results_4 = pd.read_csv('../data/compare_models_features/classification_model_relevant_stats.csv')
results_5 = pd.read_csv('../data/compare_models_features/classification_model_compare_talbe_revelvant.csv')
results_6 = pd.read_csv('../data/compare_models_features/classification_model_compare_removed_columns.csv')
results_7 = pd.read_csv('../data/compare_models_features/classification_model_compare_XGB.csv')
results_8 = pd.read_csv('../data/compare_models_features/classification_compare_card_features.csv')
results_9 = pd.read_csv('../data/compare_models_features/classification_compare_card_features_round2.csv')
results_10 = pd.read_csv('../data/compare_models_features/classification_compare_card_features_round3.csv')
results_11 = pd.read_csv('../data/compare_models_features/classification_compare_card_features_weighted_vpip.csv')
results_12 = pd.read_csv('../data/classification_compare_card_features_limpers&callers.csv')
results_13 = pd.read_csv('../data/classification_compare_default_features.csv')
results_14 = pd.read_csv('../data/classification_compare_limpers_low_high_card.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-df56aa42e35f> in <module>
#      10 results_10 = pd.read_csv('../data/compare_models_features/classification_compare_card_features_round3.csv')
#      11 results_11 = pd.read_csv('../data/compare_models_features/classification_compare_card_features_weighted_vpip.csv')
# ---> 12 results_12 = pd.read_csv('../data/classification_compare_card_features_limpers&callers.csv')
#      13 results_13 = pd.read_csv('../data/classification_compare_default_features.csv')
#      14 results_14 = pd.read_csv('../data/classification_compare_limpers_low_high_card.csv')
#
# ...

# %%
results_12.sort_values('roc_auc', ascending=False)

# %%
results_12.sort_values('brier')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-deda19d34858> in <module>
# ----> 1 results_12.sort_values('brier')
#
# NameError: name 'results_12' is not defined

# %%
results_2.sort_values('roc_auc', ascending=False)
# Out:
#     Unnamed: 0          model  \
# 15          15  GradientBoost
# 12          12  GradientBoost
# 13          13  GradientBoost
# 14          14  GradientBoost
# 10          10  GradientBoost
# 11          11  GradientBoost
# 23          23       AdaBoost
# 22          22       AdaBoost
# 20          20       AdaBoost
# 21          21       AdaBoost
# 9            9  GradientBoost
# 19          19       AdaBoost
# 18          18       AdaBoost
# 8            8  GradientBoost
# 17          17       AdaBoost
# 36          36       logistic
# 16          16       AdaBoost
# 39          39       logistic
# 34          34       logistic
# 38          38       logistic
# 33          33       logistic
# 37          37       logistic
# 32          32       logistic
# 35          35       logistic
# 4            4   RandomForest
# 5            5   RandomForest
# 6            6   RandomForest
# 3            3   RandomForest
# 7            7   RandomForest
# 1            1   RandomForest
# ...

# %%
results_2.sort_values('brier')
# Out:
#     Unnamed: 0          model  \
# 15          15  GradientBoost
# 12          12  GradientBoost
# 13          13  GradientBoost
# 14          14  GradientBoost
# 11          11  GradientBoost
# 10          10  GradientBoost
# 9            9  GradientBoost
# 8            8  GradientBoost
# 36          36       logistic
# 39          39       logistic
# 34          34       logistic
# 38          38       logistic
# 33          33       logistic
# 37          37       logistic
# 32          32       logistic
# 35          35       logistic
# 5            5   RandomForest
# 7            7   RandomForest
# 2            2   RandomForest
# 3            3   RandomForest
# 4            4   RandomForest
# 6            6   RandomForest
# 1            1   RandomForest
# 0            0   RandomForest
# 23          23       AdaBoost
# 21          21       AdaBoost
# 19          19       AdaBoost
# 20          20       AdaBoost
# 22          22       AdaBoost
# 18          18       AdaBoost
# ...

# %%
results_3.sort_values('roc_auc', ascending=False)

# %%
results_3.sort_values('brier')

# %%
results_4.sort_values('roc_auc', ascending=False)

# %%
results_4.sort_values('brier')

# %%
results_5.sort_values('roc_auc', ascending=False)

# %%
results_5.sort_values('brier')

# %%
results_6.sort_values('roc_auc', ascending=False)

# %%
results_6.sort_values('brier')

# %%
results_7.sort_values('roc_auc', ascending=False)

# %%
results_7.sort_values('brier')

# %%
results_8.sort_values('roc_auc', ascending=False)

# %%
results_8.sort_values('brier')

# %%
results_9.sort_values('roc_auc', ascending=False)

# %%
results_9.sort_values('brier')

# %%
results_10.sort_values('roc_auc', ascending=False)

# %%
results_10.sort_values('brier')

# %%
results_11.sort_values('roc_auc', ascending=False)

# %%
results_11.sort_values('brier')

# %%
results_13.sort_values('roc_auc', ascending=False)
# Out:
#     Unnamed: 0          model  \
# 17          17  GradientBoost
# 19          19  GradientBoost
# 15          15  GradientBoost
# 16          16  GradientBoost
# 14          14  GradientBoost
# 18          18  GradientBoost
# 11          11  GradientBoost
# 13          13  GradientBoost
# 25          25       AdaBoost
# 29          29       AdaBoost
# 26          26       AdaBoost
# 27          27       AdaBoost
# 28          28       AdaBoost
# 21          21       AdaBoost
# 24          24       AdaBoost
# 12          12  GradientBoost
# 23          23       AdaBoost
# 49          49       logistic
# 46          46       logistic
# 47          47       logistic
# 45          45       logistic
# 44          44       logistic
# 43          43       logistic
# 48          48       logistic
# 22          22       AdaBoost
# 41          41       logistic
# 42          42       logistic
# 8            8   RandomForest
# 6            6   RandomForest
# 9            9   RandomForest
# ...

# %%
results_13.sort_values('brier')
# Out:
#     Unnamed: 0          model  \
# 19          19  GradientBoost
# 17          17  GradientBoost
# 15          15  GradientBoost
# 18          18  GradientBoost
# 16          16  GradientBoost
# 14          14  GradientBoost
# 13          13  GradientBoost
# 11          11  GradientBoost
# 12          12  GradientBoost
# 49          49       logistic
# 46          46       logistic
# 47          47       logistic
# 45          45       logistic
# 44          44       logistic
# 43          43       logistic
# 48          48       logistic
# 41          41       logistic
# 42          42       logistic
# 10          10  GradientBoost
# 40          40       logistic
# 9            9   RandomForest
# 3            3   RandomForest
# 4            4   RandomForest
# 8            8   RandomForest
# 1            1   RandomForest
# 5            5   RandomForest
# 2            2   RandomForest
# 7            7   RandomForest
# 6            6   RandomForest
# 29          29       AdaBoost
# ...

# %%
results_13['columns'].iloc[17]
# Out:
# "['limpers', 'suited', 'position', 'high_card', 'raises&reraises', 'num_players_before', 'num_players_after', 'card_rank']"

# %%
results_13['columns'].iloc[19]
# Out:
# "['suited', 'low_card', 'position', 'high_card', 'raises&reraises', 'num_players_before', 'num_players_after', 'card_rank']"

# %%
results_13['columns'].iloc[15]
# Out:
# "['limpers', 'suited', 'low_card', 'position', 'raises&reraises', 'num_players_before', 'num_players_after', 'card_rank']"

# %%
results_13['columns'].iloc[18]
# Out:
# "['limpers', 'low_card', 'position', 'high_card', 'raises&reraises', 'num_players_before', 'num_players_after', 'card_rank']"

# %% [markdown]
# ### Features that seem to definitely prefer inclusion
# suited, position, high_card, raises&reraises, num_players_before, num_players_after, card_rank

# %% [markdown]
# ### Features that I could maybe do without
# limpers, low_card, high_card

# %%
results_14.sort_values('roc_auc', ascending=False)
# Out:
#     Unnamed: 0          model                               columns     brier  \
# 13          13  GradientBoost              ['limpers', 'high_card']  0.212575
# 14          14  GradientBoost             ['low_card', 'high_card']  0.212505
# 11          11  GradientBoost                         ['high_card']  0.212669
# 15          15  GradientBoost  ['limpers', 'low_card', 'high_card']  0.212844
# 8            8  GradientBoost                                    []  0.213042
# 10          10  GradientBoost                          ['low_card']  0.212951
# 9            9  GradientBoost                           ['limpers']  0.213047
# 12          12  GradientBoost               ['limpers', 'low_card']  0.213107
# 18          18       AdaBoost                          ['low_card']  0.248368
# 20          20       AdaBoost               ['limpers', 'low_card']  0.248379
# 22          22       AdaBoost             ['low_card', 'high_card']  0.248353
# ...

# %%
results_14.sort_values('brier')
# Out:
#     Unnamed: 0          model                               columns     brier  \
# 14          14  GradientBoost             ['low_card', 'high_card']  0.212505
# 13          13  GradientBoost              ['limpers', 'high_card']  0.212575
# 11          11  GradientBoost                         ['high_card']  0.212669
# 15          15  GradientBoost  ['limpers', 'low_card', 'high_card']  0.212844
# 10          10  GradientBoost                          ['low_card']  0.212951
# 8            8  GradientBoost                                    []  0.213042
# 9            9  GradientBoost                           ['limpers']  0.213047
# 12          12  GradientBoost               ['limpers', 'low_card']  0.213107
# 35          35       logistic                         ['high_card']  0.218535
# 38          38       logistic             ['low_card', 'high_card']  0.218548
# 32          32       logistic                                    []  0.218566
# ...

# %% [markdown]
# ### If we were to ditch any features, it would be limpers & low card from the looks of it
